# %%
import pandas as pd
import scipy as sp
import numpy as np
import csv, os
import re
import scipy.stats as stats
import networkx as nx
from collections import defaultdict

# %% [markdown]
# # Introduction
#
# The plan is to read in a bunch of fields from our various data sources and then do some stats on them. These fields are:
#
# + hashed_worker_id
# + question_code
# + num_answers_requested
# + answer_num
# + submit_datetime
# + answer
# + answer_word_count
# + start_time
# + end_time
# + originality_fil
# + originality_mike
# + originality_inverse_sum_similarity
# + utility_fil
# + utility_mike
# + realistic_fil
# + realistic_mike
# + underdefined_fil
# + underdefined_mike
# + distance_fil
# + distance_mike
# + h_cluster (heirarchical cluster value)
#
# Note that the first four fields together provide a unique way of identifying the answer (this could be better).

# %%
base_data_dirs = ['/processed_data/pilot14',
                  '/processed_data/pilot13',
                  '/processed_data/pilot12',
                  '/processed_data/pilot11',]

originality_csvs = map(lambda x: '/processed_data/pilot14_metrics/' + x + '_originality.csv',
                         ['charity', 'iPod', 'turk', 'forgot_name'])

manual_csvs = map(lambda x: '/processed_data/pilot14_metrics/' + x + '-scores.csv',
                         ['fil', 'mike'])

heirarchical_cluster_csvs = map(lambda x: '/processed_data/pilot14_metrics/' + x,
                         ['h_clusters.csv' , 'h_clusters_map.csv'])

nwf = lambda x: '/processed_data/pilot14_metrics/' + x + '-newick.csv'
output_newick = dict();
for key in ['charity', 'iPod', 'turk', 'forgot_name']:
    output_newick[key] = nwf(key)

# Read in a bunch of base data

def read_files(fils):
    rows = []
    for f in fils:
        rows = rows + read_file(f)
    return rows
     

def read_base_data(dirs):
    rows = []
    for d in dirs:
      for f in os.listdir(d):
        full_name = os.path.join(d,f)
        if os.path.isdir(full_name):
            print "I deleted the code here"
        else:
          if f == 'answers.csv':
            rows = rows + read_file(full_name)
    return rows

def read_file(f):
    with open(f) as fin:
        l = fin.readline()
        # If we see the follow, it's an early run we can ignore
        if 'Number of Answers' in l:
            return
        fin.seek(0)
        sep = '|'
        # Guess separator character
        if l.count(',') > l.count('|'):
            sep = ','
            
        # Just cache for now
        rows = []
        for row in csv.reader(fin, delimiter=sep):
            if 'hashed_worker_id' in row or 'worker_id' in row or 'cluster_parent' in row:
                continue
            rows.append(row)
            
        return rows

def clean_missing(v):
    return 0 if v == '' or v == 'missing' else v

def series_from_row(rows, index, t):
    if t == object:
        return pd.Series([row[index] for row in rows], dtype=t)
    elif t == datetime64:
        return pd.Series([np.datetime64(row[index]) for row in rows], dtype=t)
    else:
        return pd.Series([clean_missing(row[index]) for row in rows], dtype=t)

merge_column_names = ['hashed_worker_id', 'question_code', 'answer_num', 'num_requested']
    
# Read in the main processed data files
all_rows = read_base_data(base_data_dirs)
num_responses = len(all_rows)

print "num base responses:", num_responses

bad_times = [(0 if (r[9] == 'missing' or r[10] == 'missing' or int(r[9]) <=0 or int(r[10]) <= 0) else 1) for r in all_rows]

df_base = pd.DataFrame({'hashed_worker_id': pd.Series([row[0] for row in all_rows], dtype=object),
            'question_code': pd.Series([row[2] for row in all_rows], dtype=object),
            'num_requested': pd.Series([row[5] for row in all_rows], dtype=uint8),
            'answer_num': pd.Series([row[6] for row in all_rows], dtype=uint8),
            'answer': pd.Series([row[7] for row in all_rows], dtype=object),
            'answer_word_count': pd.Series([row[8] for row in all_rows], dtype=uint32),
            'submit_datetime': series_from_row(all_rows, 12, datetime64),
            'start_time': series_from_row(all_rows, 9, uint64),
            'end_time': series_from_row(all_rows, 10, uint64),
            'time_valid': pd.Series(bad_times, dtype=uint8),
})

# Read in heirarchical clusters
rows = read_file(heirarchical_cluster_csvs[0])

df = pd.merge(df_base,
              pd.DataFrame({'hashed_worker_id': series_from_row(rows, 6, object),
                  'question_code': series_from_row(rows, 0, object),
                  'num_requested': series_from_row(rows, 8, uint8),
                  'answer_num': series_from_row(rows, 5, uint8),
                  'h_cluster': series_from_row(rows, 1, uint16),
                  'h_cluster_valid': pd.Series([1 for row in rows], dtype=uint8),}),
              'outer', merge_column_names)

# Read in manual codes

def read_manual_csv(name):
    index = 0 if name == 'fil' else 1
    rows = read_file(manual_csvs[index])
    
    df = pd.DataFrame({'hashed_worker_id': series_from_row(rows, 0, object),
            'question_code': series_from_row(rows, 2, object),
            'num_requested': series_from_row(rows, 5, uint8),
            'answer_num': series_from_row(rows, 6, uint8),
            ('originality_%s' % name): series_from_row(rows, 12, uint8),
            ('utility_%s' % name): series_from_row(rows, 13, uint8),
            ('realistic_%s' % name): series_from_row(rows, 14, uint8),
            ('underdefined_%s' % name): series_from_row(rows, 15, uint8),
            ('distance_%s' % name): series_from_row(rows, 16, uint8),
            ('%s_valid' % name): pd.Series([1 for row in rows], dtype=uint8),
    })
    return df

df = pd.merge(df, read_manual_csv('mike'), 'outer', merge_column_names)
df = pd.merge(df, read_manual_csv('fil'), 'outer', merge_column_names)

# Read in exterior computeted originality (ISS) scores

all_rows = read_files(originality_csvs)

df = pd.merge(df,
              pd.DataFrame({'hashed_worker_id': series_from_row(all_rows, 4, object),
                            'question_code': series_from_row(all_rows, 7, object),
                            'answer_num': series_from_row(all_rows, 3, uint8),
                            'num_requested': series_from_row(all_rows, 6, uint8),
                            'originality_inverse_sum_similarity': series_from_row(all_rows, 2, float64),
                            'exterior_originality_valid': pd.Series([1 for row in all_rows], dtype=uint8),}),
              'outer', merge_column_names)

print "Dropping unlimited condition"
df = df[~(df['num_requested'] == 0)]

#print "Dropping runs with < num_requested responses"

print "num merged responses:", len(df)
# Out:
# num base responses: 4974
# Dropping unlimited condition
# num merged responses: 4680

# %%
number_conditions = list(set(df['num_requested']))
number_conditions = sorted(number_conditions)
print number_conditions

question_codes = list(set(df['question_code']))
print question_codes

matplotlib_colors = ['b', 'g', 'r', 'c', 'm', 'y']

question_colors = {None: matplotlib_colors[0]}
for i, code in enumerate(question_codes):
    question_colors[code] = matplotlib_colors[i+1]
print question_colors
# Out:
# [5, 10, 20, 50, 75, 100]
# ['iPod', 'turk', 'forgot_name', 'charity']
# {None: 'b', 'turk': 'r', 'iPod': 'g', 'forgot_name': 'c', 'charity': 'm'}

# %% [markdown]
# # Generate some extra columns of metrics
#
# + h_cluster_high
# + h_cluster_o_score
# + h_cluster_high_o_score
# + time_spent
# + whether run is complete (full_valid)
# + distance_from_similar
# + is_outmix
# + is_inmix

# %%
def dumb_strip(s):
    return ''.join([c for c in s if c in "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz1234567890 "])

# %%
# Compute and store a map of the heirarchical clustering

h_cluster_map = {qc: nx.DiGraph() for qc in question_codes}
h_cluster_label = {qc: dict() for qc in question_codes}

rows = read_file(heirarchical_cluster_csvs[1])
for qc, child, parent, label in rows:
    if parent != '':
        h_cluster_map[qc].add_edge(int(parent), int(child))
    else:
        h_cluster_map[qc].add_node(int(child))
    if len(label) > 0:
        h_cluster_label[qc][int(child)] = dumb_strip(label)

# Add a column for "high level" clusters (any idea in the same subgraph of the cluster map)

h_clustered = df[(df['h_cluster_valid'] > 0)]

U = {qc: nx.Graph(h_cluster_map[qc]) for qc in question_codes}
U_sgs = {qc: nx.connected_component_subgraphs(U[qc]) for qc in question_codes}

# map low level clusters to high level clusters
cluster_lookup = {qc: np.zeros(max(h_clustered['h_cluster']) + 1) for qc in question_codes}

for qc in question_codes:
    sub_df = h_clustered[(h_clustered['question_code'] == qc)]
    for low in sub_df['h_cluster']:
        if low:
            for i, high in enumerate(U_sgs[qc]):
                if low in high:
                    cluster_lookup[qc][low] = i
                    break

qcs = h_clustered['question_code']
h_clusters = h_clustered['h_cluster']


slow_list = []
for i in qcs.index:
    qc = qcs[i]
    cl = cluster_lookup[qc]
    c = h_clusters[i]
    slow_list.append(cl[c])

df['h_cluster_high'] = pd.Series([cluster_lookup[qcs[i]][h_clusters[i]] for i in qcs.index],
                                 index=qcs.index)

h_clustered = df[(df['h_cluster_valid'] > 0)]
h_cluster_highs = h_clustered['h_cluster_high']

## compute o-scores for these cluster types

p_h_cluster = dict()
p_h_cluster_high = dict()

for qc in question_codes:
    sub_df = h_clustered[(h_clustered['question_code'] == qc)]
    qc_h_clus = sub_df['h_cluster']
    
    count = np.zeros(max(sub_df['h_cluster']) + 1)
    for c in qc_h_clus:
        count[c] += 1
    p_h_cluster[qc] = count / np.sum(count)

    qc_h_clus_high = sub_df['h_cluster_high']
    
    count = np.zeros(max(sub_df['h_cluster_high']) + 1)
    for c in qc_h_clus_high:
        count[c] += 1
    p_h_cluster_high[qc] = count / np.sum(count)


s = pd.Series([1 - p_h_cluster[qcs[i]][h_clusters[i]] for i in qcs.index],
              index=qcs.index)
df['h_cluster_o_score'] = s

s = pd.Series([1 - p_h_cluster_high[qcs[i]][h_cluster_highs[i]] for i in qcs.index],
              index=qcs.index)
df['h_cluster_high_o_score'] = s

# %%
df['time_spent'] = df['end_time'] - df['start_time']

sub_df = df[(df['time_valid'] > 0)]
assert(min(sub_df['time_spent']) > 0)

# %%
fv = pd.Series([1 for i in df.index], index=df.index)

total = 0
incomplete = 0
sizes = []

for (nr, wid, qc), run in df.groupby(['num_requested', 'hashed_worker_id', 'question_code']):
    total += 1
    if len(run) < nr:
        for i in run.index:
            fv[i] = 0
        incomplete += 1
        sizes.append((nr, len(run)))
        
print "percent of incomplete runs:", float(incomplete) / total * 100.0
print sizes
            
df['full_valid'] = fv
            
sub_df = df[(df['full_valid'] == 1)]
for (nr, wid, qc), run in sub_df.groupby(['num_requested', 'hashed_worker_id', 'question_code']):
    assert(len(run) == nr)
# Out:
# percent of incomplete runs: 11.9402985075
# [(5, 3), (10, 4), (10, 6), (20, 15), (20, 13), (20, 3), (20, 10), (50, 24), (75, 25), (75, 13), (75, 22), (75, 12), (75, 55), (75, 21), (100, 10), (100, 14)]

# %% [markdown]
# ### Outmix/inmix

# %%
dist = pd.Series([0 for i in df.index], index=df.index)
im = pd.Series([0 for i in df.index], index=df.index)
om = pd.Series([0 for i in df.index], index=df.index)

for (nr, wid, qc), run in df.groupby(['num_requested', 'hashed_worker_id', 'question_code']):
    for ii, i in enumerate(run.index):
        if ii == 0:
            continue
        for jj, j in reversed(list(enumerate(run.index[0:ii]))):
            if run['h_cluster'][i] == run['h_cluster'][j]:
                dist[i] = ii - jj
                if om[j] == 0:
                    im[j] = 1
                
                om[i] = 1
                assert dist[i] > 0
                break
                
df['distance_from_similar'] = dist
df['is_inmix'] = im
df['is_outmix'] = om

# %% [markdown]
# # Convenience dataframes and completeness

# %%
print "Total # of answers:", len(df)

df = df[(df['full_valid'] == 1)]

print "Dropped incomplete runs, # answers remaining:", len(df)
manual_valid_df = df[(df['mike_valid'] > 0) & (df['fil_valid'] > 0)]
print "# of manual_valid answers:", len(manual_valid_df)
h_cluster_valid_df = df[(df['h_cluster_valid'] > 0)]
print "# of h_cluster_valid answers:", len(h_cluster_valid_df)
exterior_orig_valid_df = df[(df['exterior_originality_valid'] > 0)]
print "# of exterior_originality_valid answers:", len(exterior_orig_valid_df)
complete_valid_df = df[(df['mike_valid'] > 0) & (df['fil_valid'] > 0) & \
                       (df['time_valid'] > 0) & \
                       (df['h_cluster_valid'] > 0) & (df['exterior_originality_valid'] > 0)]
print "# of completely valid answers:", len(complete_valid_df)
time_valid_df = df[(df['time_valid'] > 0)]
print "# of time valid answers:", len(time_valid_df)
# Out:
# Total # of answers: 4680
# Dropped incomplete runs, # answers remaining: 4430
# # of manual_valid answers: 1085
# # of h_cluster_valid answers: 4430
# # of exterior_originality_valid answers: 4430
# # of completely valid answers: 1085
# # of time valid answers: 4394

# %% [markdown]
# # Generate run-level metrics
#
# + hashed_worker_id
# + question_code
# + num_answers_requested
# + submit_datetime
# + mean_word_count
# + num_manual_original
# + num_manual_original_normalized
# + num_manual_utility
# + num_manual_utility_normalized
# + num_manual_realistic
# + num_manual_underdefined

# %%
def run_count(run, pass_func):
    count = 0
    for i in run.iterrows():
        row = i[1]
        if pass_func(row):
            count += 1
    return count

def run_mean(run, value_func):
    t = 0.0
    for i in run.iterrows():
        row = i[1]
        t += value_func(row)
    return t / len(run)

runs = df.groupby(['num_requested', 'hashed_worker_id', 'question_code'])

wids = pd.Series([wid for ((nr, wid, qc), run) in runs], dtype=object)
qcs = pd.Series([qc for ((nr, wid, qc), run) in runs], dtype=object)
nrs = pd.Series([nr for ((nr, wid, qc), run) in runs], dtype=uint16)

sdts = pd.Series([np.datetime64(run['submit_datetime'][run.index[0]]) for name, run in runs],
                 dtype=datetime64)

mwc_val = lambda x: x['answer_word_count']
mwc = pd.Series([run_mean(run, mwc_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

nmo_pass = lambda x: x['originality_mike'] > 0 and \
                     x['originality_fil'] > 0 and \
                     x['distance_mike'] == 0 and \
                     x['distance_fil'] == 0
nmo = pd.Series([run_count(run, nmo_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nmo_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nmo)],
                 dtype=float64)

nmu_pass = lambda x: x['utility_mike'] == 0 and \
                     x['utility_fil'] == 0
nmu = pd.Series([run_count(run, nmu_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nmu_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nmu)],
                     dtype=float64)

# Realistic if neither of us voted it unrealistic
nmr_pass = lambda x: x['realistic_mike'] == 0 and \
                     x['realistic_fil'] == 0
nmr = pd.Series([run_count(run, nmr_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nmr_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nmr)],
                     dtype=float64)

nmun_pass = lambda x: x['underdefined_mike'] > 0 and \
                     x['underdefined_fil'] > 0
nmun = pd.Series([run_count(run, nmun_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

# %% [markdown]
# + mean_manual_distance
# + mean_originality_inverse_sum_similarity
# + num_h_cluster_low
# + num_h_cluster_high
# + num_h_cluster_low_norm
# + num_h_cluster_high_norm
# + mean_h_cluster_low_oscore
# + mean_h_cluster_high_oscore

# %%
mmd_val = lambda x: x['distance_mike'] + x['distance_fil']
mmd = pd.Series([run_mean(run, mmd_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

moiss_val = lambda x: x['originality_inverse_sum_similarity']
moiss = pd.Series([run_mean(run, moiss_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

nhcl_count = lambda run: len(set(run['h_cluster']))
nhcl = pd.Series([nhcl_count(run) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nhcl_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nhcl)],
                     dtype=float64)

nhch_count = lambda run: len(set(run['h_cluster_high']))
nhch = pd.Series([nhch_count(run) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nhch_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nhch)],
                     dtype=float64)

mhclo_val = lambda x: x['h_cluster_o_score']
mhclo = pd.Series([run_mean(run, mhclo_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

mhcho_val = lambda x: x['h_cluster_high_o_score']
mhcho = pd.Series([run_mean(run, mhcho_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

# %% [markdown]
# + num_inmix
# + num_inmix_normalized
# + num_outmix
# + num_outmix_normalized

# %%
ni = pd.Series([sum(run['is_inmix']) for ((nr, wid, qc), run) in runs],
                dtype=float64)
ni_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(ni)],
                     dtype=float64)

no = pd.Series([sum(run['is_outmix']) for ((nr, wid, qc), run) in runs],
                dtype=float64)
no_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(no)],
                     dtype=float64)

# %% [markdown]
# + manual_valid
# + h_cluster_valid
# + exterior_originality_valid
# + time_valid

# %%
mv_test = lambda run: len(run) == \
                      len(run[(run['mike_valid'] > 0) & (run['fil_valid'] > 0)])
mv = pd.Series([mv_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

hcv_test = lambda run: len(run) == len(run[(run['h_cluster_valid'] > 0)])
hcv = pd.Series([hcv_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

tv_test = lambda run: len(run) == len(run[(run['time_valid'] > 0)])
tv = pd.Series([tv_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

eov_test = lambda run: len(run) == len(run[(run['exterior_originality_valid'] > 0)])
eov = pd.Series([eov_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

# %%
run_metrics_df = pd.DataFrame({'hashed_worker_id': wids,
                            'question_code': qcs,
                            'num_requested': nrs,
                            'sumbit_datetime': sdts,
                            'mean_word_count': mwc,
                            'num_manual_original': nmo,
                            'num_manual_original_normalized': nmo_norm,
                            'num_manual_utility': nmu,
                            'num_manual_utility_normalized' : nmu_norm,
                            'num_manual_realistic': nmr,
                            'num_manual_realistic_norm': nmr_norm,
                            'num_manual_underdefined': nmun,
                            'mean_manual_distance': mmd,
                            'mean_originality_inverse_sum_similarity': moiss,
                            'num_h_cluster_low': nhcl,
                            'num_h_cluster_high': nhch,
                            'num_h_cluster_low_norm': nhcl_norm,
                            'num_h_cluster_high_norm': nhch_norm,
                            'mean_h_cluster_low_oscore': mhclo,
                            'mean_h_cluster_high_oscore': mhcho,
                            'num_inmix': ni,
                            'num_inmix_norm': ni_norm,
                            'num_outmix': no,
                            'num_outmix_norm': no_norm,
                            'manual_valid': mv,
                            'h_cluster_valid': hcv,
                            'exterior_originality_valid': eov,
                            'time_valid': tv,
                            })

assert(len(runs) == len(run_metrics_df))

# %% [markdown]
# # Convience DataFrames and completeness (runs)

# %%
print "Total # of runs:", len(run_metrics_df)
rm_manual_valid_df = run_metrics_df[(run_metrics_df['manual_valid'] > 0)]
print "# of manual_valid runs:", len(rm_manual_valid_df)
rm_h_cluster_valid_df = run_metrics_df[(run_metrics_df['h_cluster_valid'] > 0)]
print "# of h_cluster_valid runs:", len(rm_h_cluster_valid_df)
rm_exterior_orig_valid_df = run_metrics_df[(run_metrics_df['exterior_originality_valid'] > 0)]
print "# of exterior_originality_valid runs:", len(rm_exterior_orig_valid_df)
rm_time_valid_df = run_metrics_df[(run_metrics_df['time_valid'] > 0)]
print "# of time_valid runs:", len(rm_time_valid_df)

rm_complete_valid_df = run_metrics_df[(run_metrics_df['manual_valid'] > 0) & \
                          (run_metrics_df['time_valid'] > 0) & \
                          (run_metrics_df['h_cluster_valid'] > 0) & (run_metrics_df['exterior_originality_valid'] > 0)]
print "# of complete_valid runs:", len(rm_complete_valid_df)
# Out:
# Total # of runs: 118
# # of manual_valid runs: 38
# # of h_cluster_valid runs: 118
# # of exterior_originality_valid runs: 118
# # of time_valid runs: 116
# # of complete_valid runs: 38

# %% [markdown]
# # Output newick-format clustering for outside visualization

# %%
# TODO: need to do this separately for each idea code
ldf = h_cluster_valid_df

for qc in question_codes:
    sub_df = ldf[(ldf['question_code'] == qc)]
    if len(sub_df) == 0:
        continue
    
    hcm = h_cluster_map[qc]
    hcl = h_cluster_label[qc]
    
    roots = []
    for n in hcm:
        if len(hcm.predecessors(n)) == 0:
            roots.append(n)
    
    # TODO: this function should be preprocessed, but our tree traversal and selection is fast
    def num_below(n):
        num = len(sub_df[(sub_df['h_cluster'] == n)])
        for succ in hcm.successors(n):
            num += num_below(succ)
        return num
            
    def tree_string(n):
        
        children = []
        
        c = sub_df[(sub_df['h_cluster'] == n)]
        for a in c['answer']:
            fixed = dumb_strip(a)
            children.append(fixed)
    
        for succ in hcm.successors(n):
            recur = tree_string(succ)
            if not recur is None:
                children.append(tree_string(succ))
            
        if len(children) > 0:
            label = hcl[n] if n in hcl else ""
            nb = num_below(n)
            pb = "%f" % (float(nb)/ len(sub_df) * 100)
            return "(" + ','.join(children) + ")" + label + " --count-" + str(nb) + " --percent-" + pb
        else:
            return None
        
    of = output_newick[qc]
    with open(of, 'w') as f:
        s = "("
        for i, r in enumerate(roots):
            ts = tree_string(r)
            if not ts is None:
                s += ts
                if i != len(roots) - 1:
                    s += ','
        s += ");"
        f.write(s + '\n')

# %% [markdown]
# # Graphing Functions
#
# These were getting long and generic, so put them where they can be safely ignored

# %%
def init_multifig(num_conditions, fignum = 1):
    rows = math.ceil(num_conditions / float(2))
    return rows, figure(fignum, figsize=(14, rows * 5.5))

def hists(conditions, plot_title, x_title, y_title, fignum = 1):
    rc, fig = init_multifig(len(conditions), fignum)
    
    all_hist_counts = []
    for (con, color, data) in conditions:
        if type(data) is pd.Series:
            for d in data.value_counts():
                if d != 0:
                    all_hist_counts.append(d)
        else:
            for d in np.bincount(data):
                all_hist_counts.append(d)
    ymax = max(all_hist_counts)
    
    for i, (con, color, data) in enumerate(conditions):
        subplot(rc, 2, i)
        
        hist(data, alpha=0.4, color=color)
        title(plot_title + ' (' + str(con) + ')')
        xlabel(x_title)
        ylabel(y_title)
        ylim(0, ymax)

def hists_cross_nr(base_df, field, plot_title, x_title, y_title, fignum = 1):
    conditions = []
    
    for nr in number_conditions:
        nr_df = base_df[(base_df['num_requested']) == nr]
        
        if len(nr_df) == 0:
            continue
        
        conditions.append((nr, question_colors[None], nr_df[field]))
        
    hists(conditions, plot_title, x_title, y_title, fignum)

def bar_mean_err(conditions, plot_title, x_title, x_labels, y_title, fignum = 1):
    rc, fig = init_multifig(len(conditions), fignum)
    
    firstax = None
    
    ymin = None
    for c, c2, bar_datas in conditions:
        for bd in bar_datas:
            if len(bd) > 0:
                if ymin:
                    ymin = min(ymin, min(bd))
                else:
                    ymin = min(bd)
    
    for i, (con, color, bar_datas) in enumerate(conditions):
        assert(len(x_labels) == len(bar_datas))
        
        means = [np.mean(bd) for bd in bar_datas]
        stes = [stats.sem(bd, ddof=1) for bd in bar_datas]

        if firstax:
            ax = subplot(rc, 2, i, sharey=firstax)
        else:
            firstax = subplot(rc, 2, i)
            
        bar(range(len(means)), means, yerr=stes, alpha=0.4, color=color)
        xticks(range(len(means)), x_labels)
        title(plot_title + ' (' + str(con) + ')')
        xlabel(x_title)
        ylabel(y_title)
        ylim(ymin=ymin)
        
def bar_mean_err_cross_qc(base_df, field, plot_title, y_title, fignum = 1):
    conditions = []
    
    bar_datas = []
    for nr in number_conditions:
        nr_df = base_df[(base_df['num_requested']) == nr]
        bar_datas.append(nr_df[field])
    conditions.append(("all", question_colors[None], bar_datas))
    
    for qc in question_codes:
        qc_df = base_df[(base_df['question_code'] == qc)]
        bar_datas = []
        for nr in number_conditions:
            qc_nr_df = qc_df[(qc_df['num_requested']) == nr]
            bar_datas.append(qc_nr_df[field])
        conditions.append((qc, question_colors[qc], bar_datas))
        
    bar_mean_err(conditions, plot_title, '# responses requested',
                 number_conditions, y_title, fignum)
    
def bar_mean_err_cross_nr(base_df, field, plot_title, y_title, fignum = 1):
    conditions = []
    
    bar_datas = []
    for qc in question_codes:
        qc_df = base_df[(base_df['question_code']) == qc]
        bar_datas.append(qc_df[field])
    conditions.append(("all", [question_colors[qc] for qc in question_codes], bar_datas))
    
    for nr in number_conditions:
        nr_df = base_df[(base_df['num_requested'] == nr)]
        if len(nr_df) == 0:
            continue
        bar_datas = []
        for qc in question_codes:
            qc_nr_df = nr_df[(nr_df['question_code']) == qc]
            bar_datas.append(qc_nr_df[field])
        conditions.append((nr, [question_colors[qc] for qc in question_codes], bar_datas))
        
    bar_mean_err(conditions, plot_title, '# responses requested',
                 question_codes, y_title, fignum)

# %% [markdown]
# ## Worker analyis
#
# How many workers did we have? How many HITs did each complete? Did any repeat the same questions?

# %%
print "Number of runs:", len(run_metrics_df)
print "Number of turkers:", len(set(run_metrics_df['hashed_worker_id']))

number_repeats = 0
for (wid, qc), runs in run_metrics_df.groupby(['hashed_worker_id', 'question_code']):
    if len(runs) > 1:
        number_repeats += 1
        print "Worker", wid, "repeated question", qc, len(runs), "times:", list(runs['num_requested'])
print "Total number of repeats:", number_repeats
# Out:
# Number of runs: 118
# Number of turkers: 107
# Worker 07aabd7691846c27789614ea0126f9c123e2589de5668633a1749f6c repeated question forgot_name 2 times: [5, 10]
# Worker 334d753e637cea1d42a0229082d9af3ddd97835a72be29a756e06862 repeated question turk 2 times: [75, 100]
# Worker 8b29d31feb98bd21dc6388b0eb5685a4bf5fd2e80311826427c2d8bc repeated question forgot_name 2 times: [5, 20]
# Worker c05c67a7800a4de0e3ce529043575be86b107e918b2eebed56786d97 repeated question turk 2 times: [5, 10]
# Total number of repeats: 4

# %% [markdown]
# ## Conditions
#
# How many responses in each condition?

# %%
for (nr, qc), runs in run_metrics_df.groupby(['num_requested', 'question_code']):
    print len(runs), "runs in condition", qc, "/", nr
# Out:
# 5 runs in condition charity / 5
# 5 runs in condition forgot_name / 5
# 4 runs in condition iPod / 5
# 5 runs in condition turk / 5
# 5 runs in condition charity / 10
# 4 runs in condition forgot_name / 10
# 5 runs in condition iPod / 10
# 4 runs in condition turk / 10
# 6 runs in condition charity / 20
# 9 runs in condition forgot_name / 20
# 9 runs in condition iPod / 20
# 10 runs in condition turk / 20
# 4 runs in condition charity / 50
# 4 runs in condition forgot_name / 50
# 5 runs in condition iPod / 50
# 5 runs in condition turk / 50
# 2 runs in condition charity / 75
# 3 runs in condition forgot_name / 75
# 3 runs in condition iPod / 75
# 5 runs in condition turk / 75
# 3 runs in condition charity / 100
# 2 runs in condition forgot_name / 100
# 5 runs in condition iPod / 100
# 6 runs in condition turk / 100

# %% [markdown]
# # Cluster analysis
#
# We are looking to answer the following questions:
#
# + number of clusters
# + distributions of number of items in each cluster
# + summary stats of the above normalized to number of ideas collected
# + how many original ideas people are getting, how many categories they are getting
# + individual contributions vis-a-vis the clusters: how many ideas to people have that are in other clusters? How big are the clusters? If someone is generating ideas found in big clusters, this person is generating unoriginal ideas

# %% [markdown]
# ## Number of Clusters

# %%
def num_clusters(question_code):
    sub_df = h_clustered[h_clustered['question_code'] == question_code]
    return len(set(sub_df['h_cluster']))

for qc in question_codes:
    print "Question code %s" % qc
    print "\tNumber of ideas:", len(df[df['question_code'] == qc])
    print "\tNumber of clustered ideas:", len(h_clustered[(h_clustered['question_code'] == qc)])
    
    if len(h_clustered[(h_clustered['question_code'] == qc)]) == 0:
           continue
    
    print '\tNumber of "low clusters" for question code', qc, ':', num_clusters(qc)
    thing = len(h_clustered[h_clustered['question_code'] == qc])/float(num_clusters(qc))
    print "\tresponses per cluster", thing
# Out:
# Question code iPod
# 	Number of ideas: 1225
# 	Number of clustered ideas: 1275
# 	Number of "low clusters" for question code iPod : 597
# 	responses per cluster 2.13567839196
# Question code turk
# 	Number of ideas: 1490
# 	Number of clustered ideas: 1533
# 	Number of "low clusters" for question code turk : 690
# 	responses per cluster 2.22173913043
# Question code forgot_name
# 	Number of ideas: 870
# 	Number of clustered ideas: 980
# 	Number of "low clusters" for question code forgot_name : 427
# 	responses per cluster 2.29508196721
# Question code charity
# 	Number of ideas: 845
# 	Number of clustered ideas: 892
# 	Number of "low clusters" for question code charity : 439
# 	responses per cluster 2.03189066059

# %% [markdown]
# ## Cluster size frequencies for h_clusters (low)

# %%
def cluster_size_conditions_cross_qc(cluster_type):
    conditions = []

    for qc in question_codes:
        sub_df = h_cluster_valid_df[(h_cluster_valid_df['question_code'] == qc)]
        if len(sub_df) == 0:
            continue
        
        cluster_sizes = sub_df[cluster_type].value_counts()
        print len(cluster_sizes)
        cluster_sizes = [x for x in cluster_sizes if x > 0] # value_counts look for values that aren't there within the range
        conditions.append((qc, question_colors[qc], cluster_sizes))
    
    return conditions

# %%
conditions = cluster_size_conditions_cross_qc('h_cluster')
hists(conditions, 'cluster sizes (low)', '# answers in cluster', '# clusters (low)', fignum = 1)
# Out:
# 584
# 680
# 405
# 430

# %% [markdown]
# ## Cluster Size Frequencies for h_clusters (high)

# %%
conditions = cluster_size_conditions_cross_qc('h_cluster_high')
hists(conditions, 'cluster sizes (high)', '# answers in cluster', '# clusters (high)', fignum = 1)
# Out:
# 329
# 290
# 201
# 248

# %% [markdown]
# ## Number of high-level ideas

# %%
bar_mean_err_cross_qc(rm_h_cluster_valid_df, 'num_h_cluster_high_norm',
                      '# clusters (high) (normalized)', '# clusters (high) (normalized)')

# %%
bar_mean_err_cross_nr(rm_h_cluster_valid_df, 'num_h_cluster_high_norm',
                      '# clusters (high) (normalized)', '# clusters (high) (normalized)')

# %% [markdown]
# ## Number of low level clusters

# %%
bar_mean_err_cross_qc(rm_h_cluster_valid_df, 'num_h_cluster_low_norm',
                      '# clusters (low) (normalized)', '# clusters (low) (normalized)')

# %%
bar_mean_err_cross_nr(rm_h_cluster_valid_df, 'num_h_cluster_low_norm',
                      '# clusters (low) (normalized)', '# clusters (low) (normalized)')

# %% [markdown]
# ## Number of ideas over time; saturation
#
# How does the number of ideas vary as responses come in?
#
# ### high-level clusters

# %%
rows, fig = init_multifig(len(number_conditions))

for i, nr in enumerate(sorted(number_conditions)):
    sub_df = h_cluster_valid_df[(h_cluster_valid_df['num_requested'] == nr)]
    subplot(rows, 2, i + 1)
    xlabel('number of runs')
    ylabel('number of idea categories')
    title('high-level ideas over time (%i)' % nr)
    
    for qc in question_codes:
        ssub_df = sub_df[(sub_df['question_code'] == qc)]
        ssub_df = ssub_df.sort('submit_datetime')
        runs = ssub_df.groupby('hashed_worker_id')
        
        clusters = set()
        num_clusters = [0,]
        
        for name, run in runs:
            for c in run['h_cluster_high']:
                clusters.add(c)
            num_clusters.append(len(clusters))
            
        plot(num_clusters, label=qc)
    
    legend(loc='lower right')

# %%
rows, fig = init_multifig(len(number_conditions))

for i, nr in enumerate(sorted(number_conditions)):
    sub_df = h_cluster_valid_df[(h_cluster_valid_df['num_requested'] == nr)]
    subplot(rows, 2, i + 1)
    xlabel('number of runs')
    ylabel('number of idea categories')
    title('low-level ideas over time (%i)' % nr)
    
    for qc in question_codes:
        ssub_df = sub_df[(sub_df['question_code'] == qc)]
        ssub_df = ssub_df.sort('submit_datetime')
        runs = ssub_df.groupby('hashed_worker_id')
        
        clusters = set()
        num_clusters = [0,]
        
        for name, run in runs:
            assert len(run) == nr
            for c in run['h_cluster']:
                clusters.add(c)
            num_clusters.append(len(clusters))
            
        plot(num_clusters, label=qc)
    
    legend(loc='lower right')

# %% [markdown]
# # Remixing/Riffing
#
# ## Number of riffs/outmixes

# %%
bar_mean_err_cross_qc(rm_h_cluster_valid_df, 'num_outmix_norm',
                      '# outmix ideas (normalized)', '# outmix ideas')

# %%
bar_mean_err_cross_qc(rm_h_cluster_valid_df, 'num_inmix_norm',
                      '# inmix ideas (normalized)', '# inmix ideas')

# %% [markdown]
# ## Originality (manual)
#
# For a first pass, treat an idea as "original" if both Mike and I rated it >0 originality. Other possible measures in the table are:
#
# + inverse sum similarity
#
# These are good, but they both require me to institute a cutoff point over which a score is deemed original.

# %%
bar_mean_err_cross_qc(rm_manual_valid_df, 'num_manual_original_normalized',
                      '# original ideas (normalized)', '# original ideas')

# %%
bar_mean_err_cross_nr(rm_manual_valid_df, 'num_manual_original_normalized',
                      '# original ideas (normalized)', '# original ideas')

# %% [markdown]
# ## Utility (manual)

# %%
hists_cross_nr(rm_manual_valid_df, 'num_manual_utility_normalized',
               '# utility ideas (normalized)', '# utility ideas', 'number of runs')

# %%
bar_mean_err_cross_qc(rm_manual_valid_df, 'num_manual_utility_normalized',
                      '# utility ideas (normalized)', '# utility ideas')

# %%
bar_mean_err_cross_nr(rm_manual_valid_df, 'num_manual_utility_normalized',
                      '# utility ideas (normalized)', '# utility ideas')

# %% [markdown]
# ## Realisticness (manual)

# %%
bar_mean_err_cross_qc(rm_manual_valid_df, 'num_manual_realistic_norm',
                      '# realistic ideas (normalized)', '# realistic ideas')

# %%
bar_mean_err_cross_nr(rm_manual_valid_df, 'num_manual_realistic_norm',
                      '# realistic ideas (normalized)', '# realistic ideas')

# %% [markdown]
# ##Sum Similarity Originality
#
# On a lark, plot for that as well.

# %%
bar_mean_err_cross_qc(exterior_orig_valid_df, 'originality_inverse_sum_similarity', 'idea originality (ISS)', 'idea originality (ISS)')

# %%
bar_mean_err_cross_nr(exterior_orig_valid_df, 'originality_inverse_sum_similarity',
                      'idea originality (ISS)', 'idea originality (ISS)')

# %% [markdown]
# ## O-score originality based on heirarchical clustering
#
# We examine this is two ways:
#
# + "low level clustering": siblings of ideas in the cluster tree are considered the same idea
# + "high level clustering": any ideas that are connected in the graph are considered the same
#
# ### low level clustering

# %%
bar_mean_err_cross_qc(h_cluster_valid_df, 'h_cluster_o_score',
                      'h cluster low oscore', 'h cluster low oscore')

# %%
bar_mean_err_cross_nr(h_cluster_valid_df, 'h_cluster_o_score',
                      'h cluster low oscore', 'h cluster low oscore')

# %% [markdown]
# ### high level clustering

# %%
bar_mean_err_cross_qc(h_cluster_valid_df, 'h_cluster_high_o_score',
                      'h cluster high oscore', 'h cluster high oscore')

# %% [markdown]
# ## time spent

# %%
bar_mean_err_cross_qc(time_valid_df, 'time_spent',
                      'time spent per answer', 'time spent per answer')

# %%
bar_mean_err_cross_nr(time_valid_df, 'time_spent',
                      'time spent per answer', 'time spent per answer')

# %% [markdown]
# ## Correlations between measures
#
# Just going to compute correlation between each of our unique scalar measures
#
# + num_answers_requested
# + answer_word_count
# + originality_fil
# + originality_mike
# + originality_inverse_sum_similarity
# + originality_inverse_cluster_size
# + utility_fil
# + utility_mike
# + realistic_fil
# + realistic_mike
# + underdefined_fil
# + underdefined_mike
# + distance_fil
# + distance_mike

# %%
columns = ['num_requested', 'originality_fil', 'originality_mike', 'originality_inverse_sum_similarity',
           'utility_fil', 'utility_mike', 'realistic_fil', 'realistic_mike',
           'underdefined_fil', 'underdefined_mike', 'distance_fil', 'distance_mike', 'answer_word_count',
           'h_cluster_o_score', 'h_cluster_high_o_score', 'time_spent', 'is_inmix', 'is_outmix']

def pearsonr_columns(dataframe, col1, col2):
    return stats.pearsonr(dataframe[col1], dataframe[col2])

print "%-40s %-40s %s" % ("column 1", "column 2", "pearson r")

scores = []

for i, col in enumerate(columns[:-1]):
    for col2 in columns[i+1:]:
        pearsonr = pearsonr_columns(complete_valid_df, col, col2)
        scores.append((col, col2, pearsonr[0]))

scores = sorted(scores, key=lambda tup: abs(tup[2])) 

for col1, col2, pearsonr in reversed(scores):
    print "%-40s %-40s %f" % (col1, col2, pearsonr)
# Out:
# column 1                                 column 2                                 pearson r
# originality_fil                          originality_mike                         0.587352
# utility_mike                             distance_fil                             0.437005
# originality_fil                          h_cluster_o_score                        0.372186
# realistic_mike                           underdefined_fil                         0.363297
# realistic_fil                            underdefined_mike                        0.308382
# originality_mike                         h_cluster_o_score                        0.305359
# originality_mike                         originality_inverse_sum_similarity       0.302822
# underdefined_mike                        distance_mike                            0.285926
# originality_fil                          originality_inverse_sum_similarity       0.270075
# utility_mike                             is_outmix                                0.260548
# distance_fil                             is_outmix                                0.248445
# originality_mike                         h_cluster_high_o_score                   0.247158
# originality_mike                         underdefined_mike                        0.241441
# originality_mike                         distance_mike                            0.227012
# h_cluster_o_score                        is_outmix                                -0.213709
# originality_fil                          h_cluster_high_o_score                   0.209781
# utility_fil                              distance_mike                            0.202000
# originality_inverse_sum_similarity       h_cluster_o_score                        0.193598
# realistic_fil                            distance_mike                            0.192883
# originality_inverse_sum_similarity       underdefined_mike                        0.192089
# originality_fil                          underdefined_mike                        0.185355
# h_cluster_o_score                        h_cluster_high_o_score                   0.182766
# originality_fil                          underdefined_fil                         -0.175677
# originality_fil                          realistic_fil                            0.175187
# originality_inverse_sum_similarity       answer_word_count                        -0.174433
# originality_mike                         realistic_fil                            0.169365
# h_cluster_o_score                        is_inmix                                 -0.163120
# originality_fil                          answer_word_count                        0.158486
# originality_inverse_sum_similarity       h_cluster_high_o_score                   0.154962
# is_inmix                                 is_outmix                                -0.148639
# originality_fil                          distance_mike                            0.144528
# underdefined_fil                         answer_word_count                        -0.143949
# utility_fil                              is_outmix                                0.141405
# underdefined_mike                        h_cluster_o_score                        0.138110
# num_requested                            underdefined_mike                        0.137725
# answer_word_count                        h_cluster_high_o_score                   -0.133925
# realistic_fil                            h_cluster_high_o_score                   0.131842
# answer_word_count                        h_cluster_o_score                        0.127988
# underdefined_mike                        h_cluster_high_o_score                   0.127466
# realistic_mike                           h_cluster_high_o_score                   0.125470
# num_requested                            distance_fil                             0.124896
# num_requested                            is_outmix                                0.121706
# originality_inverse_sum_similarity       distance_mike                            0.121147
# num_requested                            h_cluster_o_score                        0.115641
# realistic_fil                            h_cluster_o_score                        0.114926
# distance_mike                            h_cluster_o_score                        0.112529
# num_requested                            utility_mike                             0.110394
# utility_fil                              is_inmix                                 0.107754
# num_requested                            originality_fil                          0.100080
# num_requested                            distance_mike                            0.099936
# realistic_mike                           answer_word_count                        -0.096997
# originality_mike                         underdefined_fil                         -0.096532
# num_requested                            originality_mike                         0.095175
# underdefined_fil                         is_outmix                                0.095169
# utility_fil                              underdefined_mike                        0.093363
# underdefined_fil                         h_cluster_high_o_score                   0.091805
# originality_inverse_sum_similarity       is_inmix                                 -0.087267
# originality_inverse_sum_similarity       realistic_fil                            0.086921
# distance_mike                            answer_word_count                        -0.082042
# realistic_fil                            underdefined_fil                         -0.079887
# utility_fil                              underdefined_fil                         0.079251
# realistic_fil                            time_spent                               0.078420
# originality_fil                          realistic_mike                           -0.075031
# originality_mike                         answer_word_count                        0.074385
# realistic_fil                            is_outmix                                -0.074164
# num_requested                            realistic_fil                            0.072722
# underdefined_fil                         underdefined_mike                        -0.069416
# num_requested                            realistic_mike                           -0.063676
# originality_mike                         is_inmix                                 -0.062714
# realistic_mike                           h_cluster_o_score                        -0.060122
# utility_fil                              utility_mike                             0.057846
# underdefined_fil                         distance_mike                            -0.057593
# num_requested                            is_inmix                                 0.056456
# originality_inverse_sum_similarity       utility_fil                              0.055939
# utility_fil                              h_cluster_high_o_score                   0.054907
# utility_fil                              h_cluster_o_score                        -0.053796
# num_requested                            originality_inverse_sum_similarity       0.052564
# utility_fil                              realistic_fil                            -0.052478
# underdefined_fil                         distance_fil                             -0.051356
# utility_mike                             h_cluster_high_o_score                   0.049392
# underdefined_mike                        time_spent                               -0.048921
# originality_fil                          utility_mike                             0.047098
# utility_fil                              answer_word_count                        -0.044552
# distance_mike                            time_spent                               -0.044477
# num_requested                            underdefined_fil                         -0.043383
# utility_fil                              realistic_mike                           -0.043339
# utility_mike                             is_inmix                                 -0.042070
# utility_mike                             realistic_mike                           -0.041043
# distance_fil                             is_inmix                                 -0.040447
# originality_fil                          is_inmix                                 -0.040110
# num_requested                            utility_fil                              0.040083
# originality_inverse_sum_similarity       realistic_mike                           0.039492
# realistic_fil                            distance_fil                             -0.038670
# realistic_mike                           distance_mike                            -0.038570
# originality_fil                          time_spent                               0.038416
# realistic_fil                            is_inmix                                 -0.038085
# answer_word_count                        is_outmix                                -0.037843
# time_spent                               is_outmix                                -0.037508
# realistic_mike                           distance_fil                             -0.037042
# originality_inverse_sum_similarity       time_spent                               0.035784
# utility_mike                             h_cluster_o_score                        -0.033616
# num_requested                            time_spent                               -0.032716
# utility_mike                             underdefined_mike                        -0.031379
# distance_mike                            h_cluster_high_o_score                   0.031257
# originality_inverse_sum_similarity       is_outmix                                0.030695
# realistic_mike                           underdefined_mike                        -0.030088
# underdefined_mike                        is_inmix                                 -0.029539
# originality_mike                         distance_fil                             -0.027165
# underdefined_fil                         h_cluster_o_score                        -0.026841
# distance_fil                             h_cluster_o_score                        -0.026663
# h_cluster_high_o_score                   is_inmix                                 -0.026603
# realistic_mike                           is_outmix                                0.026053
# num_requested                            answer_word_count                        -0.024322
# distance_fil                             distance_mike                            0.024172
# originality_mike                         is_outmix                                -0.023807
# distance_fil                             answer_word_count                        -0.023522
# answer_word_count                        time_spent                               -0.022995
# underdefined_mike                        distance_fil                             0.022447
# originality_fil                          distance_fil                             -0.021476
# utility_mike                             realistic_fil                            -0.020771
# realistic_mike                           is_inmix                                 -0.020609
# distance_fil                             time_spent                               -0.020505
# originality_mike                         utility_fil                              0.018675
# underdefined_mike                        answer_word_count                        -0.018022
# time_spent                               is_inmix                                 -0.017956
# underdefined_mike                        is_outmix                                -0.017749
# h_cluster_o_score                        time_spent                               -0.016698
# underdefined_fil                         is_inmix                                 -0.016408
# originality_inverse_sum_similarity       distance_fil                             -0.016387
# originality_mike                         utility_mike                             0.016055
# underdefined_fil                         time_spent                               -0.015607
# distance_mike                            is_inmix                                 -0.015146
# originality_mike                         time_spent                               0.014862
# utility_mike                             underdefined_fil                         -0.013137
# realistic_fil                            realistic_mike                           0.013112
# utility_fil                              distance_fil                             0.012697
# utility_mike                             answer_word_count                        -0.012615
# originality_mike                         realistic_mike                           0.010920
# realistic_fil                            answer_word_count                        0.010380
# utility_mike                             distance_mike                            -0.010226
# utility_mike                             time_spent                               -0.010154
# originality_inverse_sum_similarity       utility_mike                             0.009460
# answer_word_count                        is_inmix                                 -0.008769
# distance_mike                            is_outmix                                0.007162
# distance_fil                             h_cluster_high_o_score                   -0.005916
# originality_fil                          utility_fil                              -0.005879
# originality_inverse_sum_similarity       underdefined_fil                         -0.004726
# originality_fil                          is_outmix                                0.004674
# h_cluster_high_o_score                   time_spent                               0.003882
# utility_fil                              time_spent                               0.003778
# h_cluster_high_o_score                   is_outmix                                -0.002863
# realistic_mike                           time_spent                               -0.002710
# num_requested                            h_cluster_high_o_score                   0.002510

# %% [markdown]
# ## Correlation between run metrics
#
# + num_answers_requested
# + mean_word_count
# + num_manual_original_normalized
# + num_manual_utility_normalized
# + num_manual_realistic
# + num_manual_underdefined
# + mean_manual_distance
# + mean_originality_inverse_sum_similarity
# + num_h_cluster_low_norm
# + num_h_cluster_high_norm
# + mean_h_cluster_low_oscore
# + mean_h_cluster_high_oscore

# %%
columns = ['num_requested', 'mean_word_count', 'num_manual_original_normalized',
           'num_manual_utility_normalized', 'num_manual_realistic_norm', 'num_manual_underdefined',
           'mean_manual_distance', 'mean_originality_inverse_sum_similarity',
           'num_h_cluster_low_norm', 'num_h_cluster_high_norm',
           'mean_h_cluster_low_oscore', 'mean_h_cluster_high_oscore',
           'num_inmix_norm', 'num_outmix_norm']

print "%-40s %-40s %s" % ("column 1", "column 2", "pearson r")

scores = []

for i, col in enumerate(columns[:-1]):
    for col2 in columns[i+1:]:
        pearsonr = pearsonr_columns(rm_complete_valid_df, col, col2)
        scores.append((col, col2, pearsonr[0]))

scores = sorted(scores, key=lambda tup: abs(tup[2]))

for col1, col2, pearsonr in reversed(scores):
    print "%-40s %-40s %f" % (col1, col2, pearsonr)
# Out:
# column 1                                 column 2                                 pearson r
# num_h_cluster_low_norm                   num_outmix_norm                          -1.000000
# num_h_cluster_low_norm                   num_inmix_norm                           -0.877403
# num_inmix_norm                           num_outmix_norm                          0.877403
# num_requested                            mean_manual_distance                     0.668057
# num_manual_realistic_norm                mean_h_cluster_high_oscore               -0.667648
# mean_originality_inverse_sum_similarity  mean_h_cluster_high_oscore               0.664953
# num_h_cluster_low_norm                   num_h_cluster_high_norm                  0.619772
# num_h_cluster_high_norm                  num_outmix_norm                          -0.619772
# num_requested                            num_h_cluster_high_norm                  -0.602463
# mean_manual_distance                     num_h_cluster_high_norm                  -0.583933
# num_manual_utility_normalized            num_h_cluster_low_norm                   0.577987
# num_manual_utility_normalized            num_outmix_norm                          -0.577987
# num_manual_underdefined                  num_h_cluster_low_norm                   -0.564385
# num_manual_underdefined                  num_outmix_norm                          0.564385
# num_manual_realistic_norm                mean_originality_inverse_sum_similarity  -0.534108
# num_manual_original_normalized           mean_originality_inverse_sum_similarity  0.529389
# num_manual_utility_normalized            num_inmix_norm                           -0.521358
# num_manual_original_normalized           mean_h_cluster_high_oscore               0.511560
# num_h_cluster_high_norm                  num_inmix_norm                           -0.509332
# num_requested                            num_h_cluster_low_norm                   -0.476299
# num_requested                            num_outmix_norm                          0.476299
# mean_manual_distance                     num_outmix_norm                          0.468516
# mean_manual_distance                     num_h_cluster_low_norm                   -0.468516
# num_manual_utility_normalized            num_h_cluster_high_norm                  0.467470
# mean_manual_distance                     num_inmix_norm                           0.430734
# num_manual_original_normalized           mean_h_cluster_low_oscore                0.413867
# num_manual_utility_normalized            num_manual_underdefined                  -0.410606
# mean_originality_inverse_sum_similarity  mean_h_cluster_low_oscore                0.402140
# num_requested                            mean_h_cluster_low_oscore                0.364830
# mean_word_count                          mean_h_cluster_high_oscore               -0.358507
# num_requested                            num_inmix_norm                           0.358085
# num_manual_underdefined                  num_h_cluster_high_norm                  -0.332597
# mean_word_count                          mean_originality_inverse_sum_similarity  -0.332018
# num_manual_utility_normalized            mean_manual_distance                     -0.328006
# num_manual_utility_normalized            mean_h_cluster_low_oscore                0.319652
# num_manual_underdefined                  mean_manual_distance                     0.304355
# num_manual_underdefined                  num_inmix_norm                           0.297256
# mean_h_cluster_low_oscore                mean_h_cluster_high_oscore               0.274091
# num_requested                            mean_originality_inverse_sum_similarity  0.248592
# num_h_cluster_high_norm                  mean_h_cluster_high_oscore               0.242123
# mean_originality_inverse_sum_similarity  num_h_cluster_low_norm                   -0.219906
# mean_originality_inverse_sum_similarity  num_outmix_norm                          0.219906
# num_manual_realistic_norm                num_h_cluster_high_norm                  -0.217948
# mean_word_count                          num_manual_realistic_norm                0.213618
# num_requested                            num_manual_underdefined                  0.208656
# num_requested                            num_manual_original_normalized           0.203392
# mean_word_count                          num_manual_underdefined                  -0.195012
# num_manual_original_normalized           num_manual_realistic_norm                -0.186311
# num_requested                            num_manual_utility_normalized            -0.174346
# num_manual_underdefined                  mean_h_cluster_high_oscore               0.171785
# num_manual_utility_normalized            mean_originality_inverse_sum_similarity  -0.165005
# mean_h_cluster_high_oscore               num_outmix_norm                          0.161779
# num_h_cluster_low_norm                   mean_h_cluster_high_oscore               -0.161779
# num_manual_original_normalized           num_manual_underdefined                  -0.161366
# mean_word_count                          num_outmix_norm                          -0.158012
# mean_word_count                          num_h_cluster_low_norm                   0.158012
# mean_originality_inverse_sum_similarity  num_inmix_norm                           0.153764
# num_manual_realistic_norm                mean_h_cluster_low_oscore                -0.143324
# num_h_cluster_high_norm                  mean_h_cluster_low_oscore                -0.129952
# mean_word_count                          num_h_cluster_high_norm                  0.128755
# num_manual_realistic_norm                num_manual_underdefined                  -0.124922
# mean_word_count                          mean_manual_distance                     -0.124587
# num_requested                            mean_h_cluster_high_oscore               0.123830
# mean_h_cluster_high_oscore               num_inmix_norm                           0.123164
# mean_word_count                          mean_h_cluster_low_oscore                -0.114198
# mean_manual_distance                     mean_originality_inverse_sum_similarity  0.106969
# num_manual_underdefined                  mean_h_cluster_low_oscore                -0.103911
# num_manual_original_normalized           num_h_cluster_high_norm                  0.102968
# num_manual_original_normalized           mean_manual_distance                     -0.096719
# num_manual_original_normalized           num_inmix_norm                           -0.096161
# mean_h_cluster_low_oscore                num_inmix_norm                           -0.095482
# mean_word_count                          num_inmix_norm                           -0.090977
# mean_originality_inverse_sum_similarity  num_h_cluster_high_norm                  0.088748
# num_requested                            mean_word_count                          -0.082234
# num_manual_utility_normalized            num_manual_realistic_norm                0.080989
# num_manual_original_normalized           num_manual_utility_normalized            0.078127
# mean_manual_distance                     mean_h_cluster_low_oscore                0.077652
# num_manual_original_normalized           num_outmix_norm                          -0.076338
# num_manual_original_normalized           num_h_cluster_low_norm                   0.076338
# num_manual_realistic_norm                num_inmix_norm                           -0.066515
# num_requested                            num_manual_realistic_norm                -0.040249
# mean_h_cluster_low_oscore                num_outmix_norm                          -0.038782
# num_h_cluster_low_norm                   mean_h_cluster_low_oscore                0.038782
# mean_word_count                          num_manual_utility_normalized            0.018184
# num_manual_realistic_norm                num_h_cluster_low_norm                   0.012196
# num_manual_realistic_norm                num_outmix_norm                          -0.012196
# mean_word_count                          num_manual_original_normalized           0.006101
# mean_manual_distance                     mean_h_cluster_high_oscore               -0.006074
# num_manual_realistic_norm                mean_manual_distance                     0.005483
# num_manual_utility_normalized            mean_h_cluster_high_oscore               0.004960
# num_manual_underdefined                  mean_originality_inverse_sum_similarity  0.001473
