# %%
import pandas as pd
import scipy as sp
import numpy as np
import csv, os
import re
import scipy.stats as stats
import networkx as nx
from collections import defaultdict

# %% [markdown]
# # Introduction
#
# The plan is to read in a bunch of fields from our various data sources and then do some stats on them. These fields are:
#
# + hashed_worker_id
# + question_code
# + num_answers_requested
# + answer_num
# + answer
# + answer_word_count
# + start_time
# + end_time
# + originality_fil
# + originality_mike
# + originality_inverse_sum_similarity
# + utility_fil
# + utility_mike
# + realistic_fil
# + realistic_mike
# + underdefined_fil
# + underdefined_mike
# + distance_fil
# + distance_mike
# + h_cluster (heirarchical cluster value)
#
# Note that the first four fields together provide a unique way of identifying the answer (this could be better).

# %%
base_data_dirs = ['/processed_data/pilot14',
                  '/processed_data/pilot13',
                  '/processed_data/pilot12',
                  '/processed_data/pilot11',]

originality_csvs = map(lambda x: '/processed_data/pilot14_metrics/' + x + '_originality.csv',
                         ['charity', 'iPod', 'turk', 'forgot_name'])

manual_csvs = map(lambda x: '/processed_data/pilot14_metrics/' + x + '-scores.csv',
                         ['fil', 'mike'])

heirarchical_cluster_csvs = map(lambda x: '/processed_data/pilot14_metrics/' + x,
                         ['h_clusters.csv' , 'h_clusters_map.csv'])

nwf = lambda x: '/processed_data/pilot14_metrics/' + x + '-newick.csv'
output_newick = dict();
for key in ['charity', 'iPod', 'turk', 'forgot_name']:
    output_newick[key] = nwf(key)

# Read in a bunch of base data

def read_files(fils):
    rows = []
    for f in fils:
        rows = rows + read_file(f)
    return rows
     

def read_base_data(dirs):
    rows = []
    for d in dirs:
      for f in os.listdir(d):
        full_name = os.path.join(d,f)
        if os.path.isdir(full_name):
            print "I deleted the code here"
        else:
          if f == 'answers.csv':
            rows = rows + read_file(full_name)
    return rows

def read_file(f):
    with open(f) as fin:
        l = fin.readline()
        # If we see the follow, it's an early run we can ignore
        if 'Number of Answers' in l:
            return
        fin.seek(0)
        sep = '|'
        # Guess separator character
        if l.count(',') > l.count('|'):
            sep = ','
            
        # Just cache for now
        rows = []
        for row in csv.reader(fin, delimiter=sep):
            if 'hashed_worker_id' in row or 'worker_id' in row or 'cluster_parent' in row:
                continue
            rows.append(row)
            
        return rows

def clean_missing(v):
    return 0 if v == '' or v == 'missing' else v

def series_from_row(rows, index, t):
    if t == object:
        return pd.Series([row[index] for row in rows], dtype=t)
    else:
        return pd.Series([clean_missing(row[index]) for row in rows], dtype=t)

merge_column_names = ['hashed_worker_id', 'question_code', 'answer_num', 'num_requested']
    
# Read in the main processed data files
all_rows = read_base_data(base_data_dirs)
num_responses = len(all_rows)

print "num base responses:", num_responses

bad_times = [(0 if (r[9] == 'missing' or r[10] == 'missing' or int(r[9]) <=0 or int(r[10]) <= 0) else 1) for r in all_rows]

df_base = pd.DataFrame({'hashed_worker_id': pd.Series([row[0] for row in all_rows], dtype=object),
            'question_code': pd.Series([row[2] for row in all_rows], dtype=object),
            'num_requested': pd.Series([row[5] for row in all_rows], dtype=uint8),
            'answer_num': pd.Series([row[6] for row in all_rows], dtype=uint8),
            'answer': pd.Series([row[7] for row in all_rows], dtype=object),
            'answer_word_count': pd.Series([row[8] for row in all_rows], dtype=uint32),
            'start_time': series_from_row(all_rows, 9, uint64),
            'end_time': series_from_row(all_rows, 10, uint64),
            'time_valid': pd.Series(bad_times, dtype=uint8),
})

# Read in heirarchical clusters
rows = read_file(heirarchical_cluster_csvs[0])

df = pd.merge(df_base,
              pd.DataFrame({'hashed_worker_id': series_from_row(rows, 6, object),
                  'question_code': series_from_row(rows, 0, object),
                  'num_requested': series_from_row(rows, 8, uint8),
                  'answer_num': series_from_row(rows, 5, uint8),
                  'h_cluster': series_from_row(rows, 1, uint16),
                  'h_cluster_valid': pd.Series([1 for row in rows], dtype=uint8),}),
              'outer', merge_column_names)

# Read in manual codes

def read_manual_csv(name):
    index = 0 if name == 'fil' else 1
    rows = read_file(manual_csvs[index])
    
    df = pd.DataFrame({'hashed_worker_id': series_from_row(rows, 0, object),
            'question_code': series_from_row(rows, 2, object),
            'num_requested': series_from_row(rows, 5, uint8),
            'answer_num': series_from_row(rows, 6, uint8),
            ('originality_%s' % name): series_from_row(rows, 12, uint8),
            ('utility_%s' % name): series_from_row(rows, 13, uint8),
            ('realistic_%s' % name): series_from_row(rows, 14, uint8),
            ('underdefined_%s' % name): series_from_row(rows, 15, uint8),
            ('distance_%s' % name): series_from_row(rows, 16, uint8),
            ('%s_valid' % name): pd.Series([1 for row in rows], dtype=uint8),
    })
    return df

df = pd.merge(df, read_manual_csv('mike'), 'outer', merge_column_names)
df = pd.merge(df, read_manual_csv('fil'), 'outer', merge_column_names)

# Read in exterior computeted originality (ISS) scores

all_rows = read_files(originality_csvs)

df = pd.merge(df,
              pd.DataFrame({'hashed_worker_id': series_from_row(all_rows, 4, object),
                            'question_code': series_from_row(all_rows, 7, object),
                            'answer_num': series_from_row(all_rows, 3, uint8),
                            'num_requested': series_from_row(all_rows, 6, uint8),
                            'originality_inverse_sum_similarity': series_from_row(all_rows, 2, float64),
                            'exterior_originality_valid': pd.Series([1 for row in all_rows], dtype=uint8),}),
              'outer', merge_column_names)

print "Dropping unlimited condition"
df = df[~(df['num_requested'] == 0)]

print "num merged responses:", len(df)
# Out:
# num base responses: 4974
# Dropping unlimited condition
# num merged responses: 4680

# %%
number_conditions = list(set(df['num_requested']))
number_conditions = sorted(number_conditions)
print number_conditions

question_codes = list(set(df['question_code']))
print question_codes

matplotlib_colors = ['b', 'g', 'r', 'c', 'm', 'y']

question_colors = {None: matplotlib_colors[0]}
for i, code in enumerate(question_codes):
    question_colors[code] = matplotlib_colors[i+1]
print question_colors
# Out:
# [5, 10, 20, 50, 75, 100]
# ['iPod', 'turk', 'forgot_name', 'charity']
# {None: 'b', 'turk': 'r', 'iPod': 'g', 'forgot_name': 'c', 'charity': 'm'}

# %% [markdown]
# # Generate some extra columns of metrics
#
# + h_cluster_high
# + h_cluster_o_score
# + h_cluster_high_o_score
# + time_spent

# %%
def dumb_strip(s):
    return ''.join([c for c in s if c in "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz1234567890 "])

# %%
# Compute and store a map of the heirarchical clustering

h_cluster_map = {qc: nx.DiGraph() for qc in question_codes}
h_cluster_label = {qc: dict() for qc in question_codes}

rows = read_file(heirarchical_cluster_csvs[1])
for qc, child, parent, label in rows:
    if parent != '':
        h_cluster_map[qc].add_edge(int(parent), int(child))
    else:
        h_cluster_map[qc].add_node(int(child))
    if len(label) > 0:
        h_cluster_label[qc][int(child)] = dumb_strip(label)

# Add a column for "high level" clusters (any idea in the same subgraph of the cluster map)

h_clustered = df[(df['h_cluster_valid'] > 0)]

U = {qc: nx.Graph(h_cluster_map[qc]) for qc in question_codes}
U_sgs = {qc: nx.connected_component_subgraphs(U[qc]) for qc in question_codes}

# map low level clusters to high level clusters
cluster_lookup = {qc: np.zeros(max(h_clustered['h_cluster']) + 1) for qc in question_codes}

for qc in question_codes:
    sub_df = h_clustered[(h_clustered['question_code'] == qc)]
    for low in sub_df['h_cluster']:
        if low:
            for i, high in enumerate(U_sgs[qc]):
                if low in high:
                    cluster_lookup[qc][low] = i
                    break

qcs = h_clustered['question_code']
h_clusters = h_clustered['h_cluster']


slow_list = []
for i in qcs.index:
    qc = qcs[i]
    cl = cluster_lookup[qc]
    c = h_clusters[i]
    slow_list.append(cl[c])

df['h_cluster_high'] = pd.Series([cluster_lookup[qcs[i]][h_clusters[i]] for i in qcs.index],
                                 index=qcs.index)

h_clustered = df[(df['h_cluster_valid'] > 0)]
h_cluster_highs = h_clustered['h_cluster_high']

## compute o-scores for these cluster types

p_h_cluster = dict()
p_h_cluster_high = dict()

for qc in question_codes:
    sub_df = h_clustered[(h_clustered['question_code'] == qc)]
    qc_h_clus = sub_df['h_cluster']
    
    count = np.zeros(max(sub_df['h_cluster']) + 1)
    for c in qc_h_clus:
        count[c] += 1
    p_h_cluster[qc] = count / np.sum(count)

    qc_h_clus_high = sub_df['h_cluster_high']
    
    count = np.zeros(max(sub_df['h_cluster_high']) + 1)
    for c in qc_h_clus_high:
        count[c] += 1
    p_h_cluster_high[qc] = count / np.sum(count)


s = pd.Series([1 - p_h_cluster[qcs[i]][h_clusters[i]] for i in qcs.index],
              index=qcs.index)
df['h_cluster_o_score'] = s

s = pd.Series([1 - p_h_cluster_high[qcs[i]][h_cluster_highs[i]] for i in qcs.index],
              index=qcs.index)
df['h_cluster_high_o_score'] = s

# %%
df['time_spent'] = df['end_time'] - df['start_time']

sub_df = df[(df['time_valid'] > 0)]
assert(min(sub_df['time_spent']) > 0)

# %% [markdown]
# # Convenience dataframes and completeness

# %%
print "Total # of answers:", len(df)
manual_valid_df = df[(df['mike_valid'] > 0) & (df['fil_valid'] > 0)]
print "# of manual_valid answers:", len(manual_valid_df)
h_cluster_valid_df = df[(df['h_cluster_valid'] > 0)]
print "# of h_cluster_valid answers:", len(h_cluster_valid_df)
exterior_orig_valid_df = df[(df['exterior_originality_valid'] > 0)]
print "# of exterior_originality_valid answers:", len(exterior_orig_valid_df)
complete_valid_df = df[(df['mike_valid'] > 0) & (df['fil_valid'] > 0) & \
                       (df['time_valid'] > 0) & \
                       (df['h_cluster_valid'] > 0) & (df['exterior_originality_valid'] > 0)]
print "# of completely valid answers:", len(complete_valid_df)
time_valid_df = df[(df['time_valid'] > 0)]
print "# of time valid answers:", len(time_valid_df)
# Out:
# Total # of answers: 4680
# # of manual_valid answers: 1113
# # of h_cluster_valid answers: 4680
# # of exterior_originality_valid answers: 4680
# # of completely valid answers: 1113
# # of time valid answers: 4644

# %% [markdown]
# # Generate run-level metrics
#
# + hashed_worker_id
# + question_code
# + num_answers_requested
# + mean_word_count
# + num_manual_original
# + num_manual_original_normalized
# + num_manual_utility
# + num_manual_utility_normalized
# + num_manual_realistic
# + num_manual_underdefined

# %%
def run_count(run, pass_func):
    count = 0
    for i in run.iterrows():
        row = i[1]
        if pass_func(row):
            count += 1
    return count

def run_mean(run, value_func):
    t = 0.0
    for i in run.iterrows():
        row = i[1]
        t += value_func(row)
    return t / len(run)

runs = df.groupby(['num_requested', 'hashed_worker_id', 'question_code'])

wids = pd.Series([wid for ((nr, wid, qc), run) in runs], dtype=object)
qcs = pd.Series([qc for ((nr, wid, qc), run) in runs], dtype=object)
nrs = pd.Series([nr for ((nr, wid, qc), run) in runs], dtype=uint16)

mwc_val = lambda x: x['answer_word_count']
mwc = pd.Series([run_mean(run, mwc_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

nmo_pass = lambda x: x['originality_mike'] > 0 and \
                     x['originality_fil'] > 0 and \
                     x['distance_mike'] == 0 and \
                     x['distance_fil'] == 0
nmo = pd.Series([run_count(run, nmo_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nmo_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nmo)],
                 dtype=float64)

nmu_pass = lambda x: x['utility_mike'] == 0 and \
                     x['utility_fil'] == 0
nmu = pd.Series([run_count(run, nmu_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nmu_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nmu)],
                     dtype=float64)

nmr_pass = lambda x: x['realistic_mike'] > 0 and \
                     x['realistic_fil'] > 0
nmr = pd.Series([run_count(run, nmr_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nmun_pass = lambda x: x['underdefined_mike'] > 0 and \
                     x['underdefined_fil'] > 0
nmun = pd.Series([run_count(run, nmun_pass) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

# %% [markdown]
# + mean_manual_distance
# + mean_originality_inverse_sum_similarity
# + num_h_cluster_low
# + num_h_cluster_high
# + num_h_cluster_low_norm
# + num_h_cluster_high_norm
# + mean_h_cluster_low_oscore
# + mean_h_cluster_high_oscore

# %%
mmd_val = lambda x: x['distance_mike'] + x['distance_fil']
mmd = pd.Series([run_mean(run, mmd_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

moiss_val = lambda x: x['originality_inverse_sum_similarity']
moiss = pd.Series([run_mean(run, moiss_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

nhcl_count = lambda run: len(set(run['h_cluster']))
nhcl = pd.Series([nhcl_count(run) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nhcl_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nhcl)],
                     dtype=float64)

nhch_count = lambda run: len(set(run['h_cluster_high']))
nhch = pd.Series([nhch_count(run) for ((nr, wid, qc), run) in runs],
                dtype=uint16)

nhch_norm = pd.Series([float(n) / nrs[i] for (i, n) in enumerate(nhch)],
                     dtype=float64)

mhclo_val = lambda x: x['h_cluster_o_score']
mhclo = pd.Series([run_mean(run, mhclo_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

mhcho_val = lambda x: x['h_cluster_high_o_score']
mhcho = pd.Series([run_mean(run, mhcho_val) for ((nr, wid, qc), run) in runs],
                dtype=float64)

# %% [markdown]
# + manual_valid
# + h_cluster_valid
# + exterior_originality_valid
# + time_valid

# %%
mv_test = lambda run: len(run) == \
                      len(run[(run['mike_valid'] > 0) & (run['fil_valid'] > 0)])
mv = pd.Series([mv_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

hcv_test = lambda run: len(run) == len(run[(run['h_cluster_valid'] > 0)])
hcv = pd.Series([hcv_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

tv_test = lambda run: len(run) == len(run[(run['time_valid'] > 0)])
tv = pd.Series([tv_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

eov_test = lambda run: len(run) == len(run[(run['exterior_originality_valid'] > 0)])
eov = pd.Series([eov_test(run) for ((nr, wid, qc), run) in runs],
                dtype=uint8)

# %%
run_metrics_df = pd.DataFrame({'hashed_worker_id': wids,
                            'question_code': qcs,
                            'num_requested': nrs,
                            'mean_word_count': mwc,
                            'num_manual_original': nmo,
                            'num_manual_original_normalized': nmo_norm,
                            'num_manual_utility': nmu,
                            'num_manual_utility_normalized' : nmu_norm,
                            'num_manual_realistic': nmr,
                            'num_manual_underdefined': nmun,
                            'mean_manual_distance': mmd,
                            'mean_originality_inverse_sum_similarity': moiss,
                            'num_h_cluster_low': nhcl,
                            'num_h_cluster_high': nhch,
                            'num_h_cluster_low_norm': nhcl_norm,
                            'num_h_cluster_high_norm': nhch_norm,
                            'mean_h_cluster_low_oscore': mhclo,
                            'mean_h_cluster_high_oscore': mhcho,
                            'manual_valid': mv,
                            'h_cluster_valid': hcv,
                            'exterior_originality_valid': eov,
                            'time_valid': tv,
                            })

assert(len(runs) == len(run_metrics_df))

# %% [markdown]
# # Convience DataFrames and completeness (runs)

# %%
print "Total # of runs:", len(run_metrics_df)
rm_manual_valid_df = run_metrics_df[(run_metrics_df['manual_valid'] > 0)]
print "# of manual_valid runs:", len(rm_manual_valid_df)
rm_h_cluster_valid_df = run_metrics_df[(run_metrics_df['h_cluster_valid'] > 0)]
print "# of h_cluster_valid runs:", len(rm_h_cluster_valid_df)
rm_exterior_orig_valid_df = run_metrics_df[(run_metrics_df['exterior_originality_valid'] > 0)]
print "# of exterior_originality_valid runs:", len(rm_exterior_orig_valid_df)
rm_time_valid_df = run_metrics_df[(run_metrics_df['time_valid'] > 0)]
print "# of time_valid runs:", len(rm_time_valid_df)

rm_complete_valid_df = run_metrics_df[(run_metrics_df['manual_valid'] > 0) & \
                          (run_metrics_df['time_valid'] > 0) & \
                          (run_metrics_df['h_cluster_valid'] > 0) & (run_metrics_df['exterior_originality_valid'] > 0)]
print "# of complete_valid runs:", len(rm_complete_valid_df)
# Out:
# Total # of runs: 134
# # of manual_valid runs: 40
# # of h_cluster_valid runs: 134
# # of exterior_originality_valid runs: 134
# # of time_valid runs: 132
# # of complete_valid runs: 40

# %% [markdown]
# # Output newick-format clustering for outside visualization

# %%
# TODO: need to do this separately for each idea code
ldf = h_cluster_valid_df

for qc in question_codes:
    sub_df = ldf[(ldf['question_code'] == qc)]
    if len(sub_df) == 0:
        continue
    
    hcm = h_cluster_map[qc]
    hcl = h_cluster_label[qc]
    
    roots = []
    for n in hcm:
        if len(hcm.predecessors(n)) == 0:
            roots.append(n)
    
    # TODO: this function should be preprocessed, but our tree traversal and selection is fast
    def num_below(n):
        num = len(sub_df[(sub_df['h_cluster'] == n)])
        for succ in hcm.successors(n):
            num += num_below(succ)
        return num
            
    def tree_string(n):
        
        children = []
        
        c = sub_df[(sub_df['h_cluster'] == n)]
        for a in c['answer']:
            fixed = dumb_strip(a)
            children.append(fixed)
    
        for succ in hcm.successors(n):
            recur = tree_string(succ)
            if not recur is None:
                children.append(tree_string(succ))
            
        if len(children) > 0:
            label = hcl[n] if n in hcl else ""
            nb = num_below(n)
            pb = "%f" % (float(nb)/ len(sub_df) * 100)
            return "(" + ','.join(children) + ")" + label + " --count-" + str(nb) + " --percent-" + pb
        else:
            return None
        
    of = output_newick[qc]
    with open(of, 'w') as f:
        s = "("
        for i, r in enumerate(roots):
            ts = tree_string(r)
            if not ts is None:
                s += ts
                if i != len(roots) - 1:
                    s += ','
        s += ");"
        f.write(s + '\n')

# %% [markdown]
# # Graphing Functions
#
# These were getting long and generic, so put them where they can be safely ignored

# %%
def init_multifig(num_conditions, fignum):
    rows = math.ceil(num_conditions / float(2))
    return rows, figure(fignum, figsize=(14, rows * 5.5))

def hists(conditions, plot_title, x_title, y_title, fignum = 1):
    rc, fig = init_multifig(len(conditions), fignum)
    
    all_hist_counts = []
    for (con, color, data) in conditions:
        if type(data) is pd.Series:
            for d in data.value_counts():
                if d != 0:
                    all_hist_counts.append(d)
        else:
            for d in np.bincount(data):
                all_hist_counts.append(d)
    ymax = max(all_hist_counts)
    
    for i, (con, color, data) in enumerate(conditions):
        subplot(rc, 2, i)
        
        hist(data, alpha=0.4, color=color)
        title(plot_title + ' (' + str(con) + ')')
        xlabel(x_title)
        ylabel(y_title)
        ylim(0, ymax)

def hists_cross_nr(base_df, field, plot_title, x_title, y_title, fignum = 1):
    conditions = []
    
    for nr in number_conditions:
        nr_df = base_df[(base_df['num_requested']) == nr]
        
        if len(nr_df) == 0:
            continue
        
        conditions.append((nr, question_colors[None], nr_df[field]))
        
    hists(conditions, plot_title, x_title, y_title, fignum)

def bar_mean_err(conditions, plot_title, x_title, x_labels, y_title, fignum = 1):
    rc, fig = init_multifig(len(conditions), fignum)
    
    firstax = None
    
    ymin = None
    for c, c2, bar_datas in conditions:
        for bd in bar_datas:
            if len(bd) > 0:
                if ymin:
                    ymin = min(ymin, min(bd))
                else:
                    ymin = min(bd)
    
    for i, (con, color, bar_datas) in enumerate(conditions):
        assert(len(x_labels) == len(bar_datas))
        
        means = [np.mean(bd) for bd in bar_datas]
        stes = [stats.sem(bd, ddof=1) for bd in bar_datas]

        if firstax:
            ax = subplot(rc, 2, i, sharey=firstax)
        else:
            firstax = subplot(rc, 2, i)
            
        bar(range(len(means)), means, yerr=stes, alpha=0.4, color=color)
        xticks(range(len(means)), x_labels)
        title(plot_title + ' (' + str(con) + ')')
        xlabel(x_title)
        ylabel(y_title)
        ylim(ymin=ymin)
        
def bar_mean_err_cross_qc(base_df, field, plot_title, y_title, fignum = 1):
    conditions = []
    
    bar_datas = []
    for nr in number_conditions:
        nr_df = base_df[(base_df['num_requested']) == nr]
        bar_datas.append(nr_df[field])
    conditions.append(("all", question_colors[None], bar_datas))
    
    for qc in question_codes:
        qc_df = base_df[(base_df['question_code'] == qc)]
        bar_datas = []
        for nr in number_conditions:
            qc_nr_df = qc_df[(qc_df['num_requested']) == nr]
            bar_datas.append(qc_nr_df[field])
        conditions.append((qc, question_colors[qc], bar_datas))
        
    bar_mean_err(conditions, plot_title, '# responses requested',
                 number_conditions, y_title, fignum)
    
def bar_mean_err_cross_nr(base_df, field, plot_title, y_title, fignum = 1):
    conditions = []
    
    bar_datas = []
    for qc in question_codes:
        qc_df = base_df[(base_df['question_code']) == qc]
        bar_datas.append(qc_df[field])
    conditions.append(("all", [question_colors[qc] for qc in question_codes], bar_datas))
    
    for nr in number_conditions:
        nr_df = base_df[(base_df['num_requested'] == nr)]
        if len(nr_df) == 0:
            continue
        bar_datas = []
        for qc in question_codes:
            qc_nr_df = nr_df[(nr_df['question_code']) == qc]
            bar_datas.append(qc_nr_df[field])
        conditions.append((nr, [question_colors[qc] for qc in question_codes], bar_datas))
        
    bar_mean_err(conditions, plot_title, '# responses requested',
                 question_codes, y_title, fignum)

# %% [markdown]
# # Cluster analysis
#
# We are looking to answer the following questions:
#
# + number of clusters
# + distributions of number of items in each cluster
# + summary stats of the above normalized to number of ideas collected
# + how many original ideas people are getting, how many categories they are getting
# + individual contributions vis-a-vis the clusters: how many ideas to people have that are in other clusters? How big are the clusters? If someone is generating ideas found in big clusters, this person is generating unoriginal ideas

# %% [markdown]
# ## Number of Clusters

# %%
def num_clusters(question_code):
    sub_df = h_clustered[h_clustered['question_code'] == question_code]
    return len(set(sub_df['h_cluster']))

for qc in question_codes:
    print "Question code %s" % qc
    print "\tNumber of ideas:", len(df[df['question_code'] == qc])
    print "\tNumber of clustered ideas:", len(h_clustered[(h_clustered['question_code'] == qc)])
    
    if len(h_clustered[(h_clustered['question_code'] == qc)]) == 0:
           continue
    
    print '\tNumber of "low clusters" for question code', qc, ':', num_clusters(qc)
    thing = len(h_clustered[h_clustered['question_code'] == qc])/float(num_clusters(qc))
    print "\tresponses per cluster", thing
# Out:
# Question code iPod
# 	Number of ideas: 1275
# 	Number of clustered ideas: 1275
# 	Number of "low clusters" for question code iPod : 597
# 	responses per cluster 2.13567839196
# Question code turk
# 	Number of ideas: 1533
# 	Number of clustered ideas: 1533
# 	Number of "low clusters" for question code turk : 690
# 	responses per cluster 2.22173913043
# Question code forgot_name
# 	Number of ideas: 980
# 	Number of clustered ideas: 980
# 	Number of "low clusters" for question code forgot_name : 427
# 	responses per cluster 2.29508196721
# Question code charity
# 	Number of ideas: 892
# 	Number of clustered ideas: 892
# 	Number of "low clusters" for question code charity : 439
# 	responses per cluster 2.03189066059

# %% [markdown]
# ## Cluster size frequencies for h_clusters (low)

# %%
def cluster_size_conditions_cross_qc(cluster_type):
    conditions = []

    for qc in question_codes:
        sub_df = h_cluster_valid_df[(h_cluster_valid_df['question_code'] == qc)]
        if len(sub_df) == 0:
            continue
        
        cluster_sizes = sub_df[cluster_type].value_counts()
        print len(cluster_sizes)
        cluster_sizes = [x for x in cluster_sizes if x > 0] # value_counts look for values that aren't there within the range
        conditions.append((qc, question_colors[qc], cluster_sizes))
    
    return conditions

# %%
conditions = cluster_size_conditions_cross_qc('h_cluster')
hists(conditions, 'cluster sizes (low)', '# answers in cluster', '# clusters (low)', fignum = 1)
# Out:
# 597
# 690
# 427
# 439

# %% [markdown]
# ## Cluster Size Frequencies for h_clusters (high)

# %%
conditions = cluster_size_conditions_cross_qc('h_cluster_high')
hists(conditions, 'cluster sizes (high)', '# answers in cluster', '# clusters (high)', fignum = 1)
# Out:
# 332
# 297
# 208
# 253

# %% [markdown]
# ## Number of high-level ideas

# %%
bar_mean_err_cross_qc(rm_h_cluster_valid_df, 'num_h_cluster_high_norm',
                      '# clusters (high) (normalized)', '# clusters (high) (normalized)')

# %%
bar_mean_err_cross_nr(rm_h_cluster_valid_df, 'num_h_cluster_high_norm',
                      '# clusters (high) (normalized)', '# clusters (high) (normalized)')

# %% [markdown]
# ## Originality (manual)
#
# For a first pass, treat an idea as "original" if both Mike and I rated it >0 originality. Other possible measures in the table are:
#
# + inverse sum similarity
#
# These are good, but they both require me to institute a cutoff point over which a score is deemed original.

# %%
bar_mean_err_cross_qc(rm_manual_valid_df, 'num_manual_original_normalized',
                      '# original ideas (normalized)', '# original ideas')

# %%
bar_mean_err_cross_nr(rm_manual_valid_df, 'num_manual_original_normalized',
                      '# original ideas (normalized)', '# original ideas')
# Out:
# 0.02

# %% [markdown]
# ## Utility (manual)

# %%
hists_cross_nr(rm_manual_valid_df, 'num_manual_utility_normalized',
               '# utility ideas (normalized)', '# utility ideas', 'number of runs')

# %%
bar_mean_err_cross_qc(rm_manual_valid_df, 'num_manual_utility_normalized',
                      '# utility ideas (normalized)', '# utility ideas')

# %%
bar_mean_err_cross_nr(rm_manual_valid_df, 'num_manual_utility_normalized',
                      '# utility ideas (normalized)', '# utility ideas')

# %% [markdown]
# ##Sum Similarity Originality
#
# On a lark, plot for that as well.

# %%
bar_mean_err_cross_qc(exterior_orig_valid_df, 'originality_inverse_sum_similarity', 'idea originality (ISS)', 'idea originality (ISS)')

# %%
bar_mean_err_cross_nr(exterior_orig_valid_df, 'originality_inverse_sum_similarity',
                      'idea originality (ISS)', 'idea originality (ISS)')

# %% [markdown]
# ## O-score originality based on heirarchical clustering
#
# We examine this is two ways:
#
# + "low level clustering": siblings of ideas in the cluster tree are considered the same idea
# + "high level clustering": any ideas that are connected in the graph are considered the same
#
# ### low level clustering

# %%
bar_mean_err_cross_qc(h_cluster_valid_df, 'h_cluster_o_score',
                      'h cluster low oscore', 'h cluster low oscore')
# Out:
# 0.961883408072

# %%
bar_mean_err_cross_nr(h_cluster_valid_df, 'h_cluster_o_score',
                      'h cluster low oscore', 'h cluster low oscore')
# Out:
# 0.961883408072

# %% [markdown]
# ### high level clustering

# %%
bar_mean_err_cross_qc(h_cluster_valid_df, 'h_cluster_high_o_score',
                      'h cluster high oscore', 'h cluster high oscore')
# Out:
# 0.840816326531

# %% [markdown]
# ## time spent

# %%
bar_mean_err_cross_qc(time_valid_df, 'time_spent',
                      'time spent per answer', 'time spent per answer')
# Out:
# 1443

# %%
bar_mean_err_cross_nr(time_valid_df, 'time_spent',
                      'time spent per answer', 'time spent per answer')

# %% [markdown]
# ## Correlations between measures
#
# Just going to compute correlation between each of our unique scalar measures
#
# + num_answers_requested
# + answer_word_count
# + originality_fil
# + originality_mike
# + originality_inverse_sum_similarity
# + originality_inverse_cluster_size
# + utility_fil
# + utility_mike
# + realistic_fil
# + realistic_mike
# + underdefined_fil
# + underdefined_mike
# + distance_fil
# + distance_mike

# %%
columns = ['num_requested', 'originality_fil', 'originality_mike', 'originality_inverse_sum_similarity',
           'utility_fil', 'utility_mike', 'realistic_fil', 'realistic_mike',
           'underdefined_fil', 'underdefined_mike', 'distance_fil', 'distance_mike', 'answer_word_count',
           'h_cluster_o_score', 'h_cluster_high_o_score', 'time_spent']

def pearsonr_columns(dataframe, col1, col2):
    return stats.pearsonr(dataframe[col1], dataframe[col2])

print "%-40s %-40s %s" % ("column 1", "column 2", "pearson r")

scores = []

for i, col in enumerate(columns[:-1]):
    for col2 in columns[i+1:]:
        pearsonr = pearsonr_columns(complete_valid_df, col, col2)
        scores.append((col, col2, pearsonr[0]))

scores = sorted(scores, key=lambda tup: abs(tup[2])) 

for col1, col2, pearsonr in reversed(scores):
    print "%-40s %-40s %f" % (col1, col2, pearsonr)
# Out:
# column 1                                 column 2                                 pearson r
# originality_fil                          originality_mike                         0.584951
# utility_mike                             distance_fil                             0.438154
# originality_fil                          h_cluster_o_score                        0.364801
# realistic_mike                           underdefined_fil                         0.353517
# realistic_fil                            underdefined_mike                        0.307062
# originality_mike                         h_cluster_o_score                        0.304226
# originality_mike                         originality_inverse_sum_similarity       0.294670
# underdefined_mike                        distance_mike                            0.286481
# originality_fil                          originality_inverse_sum_similarity       0.260635
# originality_mike                         underdefined_mike                        0.243998
# originality_mike                         h_cluster_high_o_score                   0.243917
# originality_mike                         distance_mike                            0.227523
# originality_fil                          h_cluster_high_o_score                   0.204931
# utility_fil                              distance_mike                            0.202822
# realistic_fil                            distance_mike                            0.190518
# originality_fil                          underdefined_mike                        0.189642
# originality_inverse_sum_similarity       underdefined_mike                        0.182686
# originality_fil                          underdefined_fil                         -0.180848
# h_cluster_o_score                        h_cluster_high_o_score                   0.176706
# originality_inverse_sum_similarity       answer_word_count                        -0.176410
# originality_fil                          realistic_fil                            0.173673
# originality_mike                         realistic_fil                            0.172605
# originality_inverse_sum_similarity       h_cluster_o_score                        0.171200
# originality_fil                          answer_word_count                        0.164018
# underdefined_fil                         answer_word_count                        -0.163727
# originality_inverse_sum_similarity       h_cluster_high_o_score                   0.156289
# originality_fil                          distance_mike                            0.144348
# num_requested                            underdefined_mike                        0.143784
# answer_word_count                        h_cluster_high_o_score                   -0.139624
# underdefined_mike                        h_cluster_o_score                        0.136018
# answer_word_count                        h_cluster_o_score                        0.134410
# num_requested                            distance_fil                             0.131498
# realistic_fil                            h_cluster_high_o_score                   0.129137
# realistic_mike                           h_cluster_high_o_score                   0.123142
# num_requested                            h_cluster_o_score                        0.122701
# underdefined_mike                        h_cluster_high_o_score                   0.122627
# num_requested                            utility_mike                             0.117052
# originality_inverse_sum_similarity       distance_mike                            0.116789
# originality_mike                         underdefined_fil                         -0.113761
# realistic_fil                            h_cluster_o_score                        0.111721
# distance_mike                            h_cluster_o_score                        0.110700
# num_requested                            distance_mike                            0.106981
# realistic_mike                           answer_word_count                        -0.103281
# num_requested                            originality_fil                          0.103066
# num_requested                            originality_mike                         0.102874
# utility_fil                              underdefined_mike                        0.095931
# underdefined_fil                         h_cluster_high_o_score                   0.093994
# realistic_fil                            underdefined_fil                         -0.089539
# originality_inverse_sum_similarity       realistic_fil                            0.083370
# originality_mike                         answer_word_count                        0.083341
# underdefined_fil                         underdefined_mike                        -0.080102
# originality_fil                          realistic_mike                           -0.078069
# realistic_fil                            time_spent                               0.077690
# num_requested                            underdefined_fil                         -0.077375
# distance_mike                            answer_word_count                        -0.074402
# realistic_mike                           h_cluster_o_score                        -0.072610
# num_requested                            realistic_fil                            0.071598
# num_requested                            realistic_mike                           -0.069261
# underdefined_fil                         h_cluster_o_score                        -0.062119
# underdefined_fil                         distance_mike                            -0.062030
# utility_fil                              utility_mike                             0.059876
# underdefined_fil                         distance_fil                             -0.056667
# originality_inverse_sum_similarity       utility_fil                              0.053884
# utility_fil                              h_cluster_high_o_score                   0.053074
# utility_fil                              underdefined_fil                         0.052197
# num_requested                            utility_fil                              0.050383
# utility_fil                              realistic_fil                            -0.048831
# underdefined_mike                        time_spent                               -0.048436
# originality_inverse_sum_similarity       realistic_mike                           0.047985
# originality_fil                          utility_mike                             0.047927
# utility_mike                             h_cluster_high_o_score                   0.047105
# utility_fil                              realistic_mike                           -0.044049
# distance_mike                            time_spent                               -0.043716
# utility_fil                              h_cluster_o_score                        -0.042777
# utility_mike                             realistic_mike                           -0.042045
# num_requested                            originality_inverse_sum_similarity       0.041794
# realistic_mike                           distance_mike                            -0.039649
# originality_fil                          time_spent                               0.038441
# realistic_mike                           distance_fil                             -0.038285
# realistic_fil                            distance_fil                             -0.037926
# utility_fil                              answer_word_count                        -0.035470
# originality_inverse_sum_similarity       time_spent                               0.035014
# realistic_mike                           underdefined_mike                        -0.033735
# utility_mike                             underdefined_mike                        -0.029100
# distance_mike                            h_cluster_high_o_score                   0.029029
# num_requested                            time_spent                               -0.028934
# utility_mike                             h_cluster_o_score                        -0.028896
# originality_mike                         utility_fil                              0.026948
# distance_fil                             distance_mike                            0.026220
# underdefined_mike                        distance_fil                             0.024815
# originality_mike                         distance_fil                             -0.024345
# distance_fil                             h_cluster_o_score                        -0.021883
# utility_mike                             underdefined_fil                         -0.020589
# answer_word_count                        time_spent                               -0.020525
# utility_mike                             realistic_fil                            -0.020202
# distance_fil                             time_spent                               -0.019788
# originality_fil                          distance_fil                             -0.019535
# originality_mike                         utility_mike                             0.018211
# originality_inverse_sum_similarity       distance_fil                             -0.018164
# originality_inverse_sum_similarity       underdefined_fil                         0.016450
# underdefined_fil                         time_spent                               -0.016265
# distance_fil                             answer_word_count                        -0.016192
# originality_mike                         time_spent                               0.015920
# utility_fil                              distance_fil                             0.015134
# h_cluster_o_score                        time_spent                               -0.012368
# realistic_fil                            answer_word_count                        0.012064
# utility_mike                             time_spent                               -0.009455
# utility_mike                             distance_mike                            -0.008165
# distance_fil                             h_cluster_high_o_score                   -0.008095
# underdefined_mike                        answer_word_count                        -0.007881
# originality_mike                         realistic_mike                           0.007577
# originality_inverse_sum_similarity       utility_mike                             0.007342
# realistic_fil                            realistic_mike                           0.007229
# num_requested                            h_cluster_high_o_score                   -0.006687
# utility_mike                             answer_word_count                        -0.006048
# num_requested                            answer_word_count                        0.005352
# originality_fil                          utility_fil                              -0.004441
# utility_fil                              time_spent                               0.004310
# realistic_mike                           time_spent                               -0.004019
# h_cluster_high_o_score                   time_spent                               0.003019

# %% [markdown]
# ## Correlation between run metrics
#
# + num_answers_requested
# + mean_word_count
# + num_manual_original_normalized
# + num_manual_utility_normalized
# + num_manual_realistic
# + num_manual_underdefined
# + mean_manual_distance
# + mean_originality_inverse_sum_similarity
# + num_h_cluster_low_norm
# + num_h_cluster_high_norm
# + mean_h_cluster_low_oscore
# + mean_h_cluster_high_oscore

# %%
columns = ['num_requested', 'mean_word_count', 'num_manual_original_normalized',
           'num_manual_utility_normalized', 'num_manual_realistic', 'num_manual_underdefined',
           'mean_manual_distance', 'mean_originality_inverse_sum_similarity',
           'num_h_cluster_low_norm', 'num_h_cluster_high_norm',
           'mean_h_cluster_low_oscore', 'mean_h_cluster_high_oscore']

print "%-40s %-40s %s" % ("column 1", "column 2", "pearson r")

scores = []

for i, col in enumerate(columns[:-1]):
    for col2 in columns[i+1:]:
        pearsonr = pearsonr_columns(rm_complete_valid_df, col, col2)
        scores.append((col, col2, pearsonr[0]))

scores = sorted(scores, key=lambda tup: abs(tup[2]))

for col1, col2, pearsonr in reversed(scores):
    print "%-40s %-40s %f" % (col1, col2, pearsonr)
# Out:
# column 1                                 column 2                                 pearson r
# mean_originality_inverse_sum_similarity  mean_h_cluster_high_oscore               0.673430
# num_requested                            mean_manual_distance                     0.671431
# num_h_cluster_low_norm                   num_h_cluster_high_norm                  0.617811
# num_requested                            num_h_cluster_high_norm                  -0.575892
# mean_manual_distance                     num_h_cluster_high_norm                  -0.534896
# num_manual_utility_normalized            num_h_cluster_low_norm                   0.506069
# num_manual_underdefined                  num_h_cluster_low_norm                   -0.495996
# num_manual_original_normalized           mean_originality_inverse_sum_similarity  0.492159
# num_manual_original_normalized           mean_h_cluster_high_oscore               0.478419
# num_manual_utility_normalized            num_h_cluster_high_norm                  0.459929
# num_manual_original_normalized           mean_h_cluster_low_oscore                0.428078
# num_requested                            num_manual_realistic                     0.422038
# num_manual_utility_normalized            num_manual_underdefined                  -0.411337
# num_requested                            num_h_cluster_low_norm                   -0.400228
# mean_word_count                          mean_h_cluster_high_oscore               -0.385042
# num_requested                            mean_h_cluster_low_oscore                0.375617
# num_manual_realistic                     mean_manual_distance                     0.374147
# mean_word_count                          mean_originality_inverse_sum_similarity  -0.362876
# mean_originality_inverse_sum_similarity  mean_h_cluster_low_oscore                0.362081
# mean_manual_distance                     num_h_cluster_low_norm                   -0.344909
# num_manual_utility_normalized            mean_manual_distance                     -0.335669
# num_manual_underdefined                  num_h_cluster_high_norm                  -0.317374
# num_manual_underdefined                  mean_manual_distance                     0.311684
# num_manual_utility_normalized            mean_h_cluster_low_oscore                0.298836
# num_manual_realistic                     mean_h_cluster_high_oscore               0.257057
# mean_originality_inverse_sum_similarity  num_h_cluster_low_norm                   -0.255460
# mean_word_count                          num_h_cluster_low_norm                   0.251368
# mean_h_cluster_low_oscore                mean_h_cluster_high_oscore               0.240247
# num_requested                            mean_originality_inverse_sum_similarity  0.225932
# mean_word_count                          num_manual_realistic                     -0.225348
# num_h_cluster_high_norm                  mean_h_cluster_high_oscore               0.221281
# num_requested                            num_manual_original_normalized           0.215146
# num_requested                            num_manual_underdefined                  0.214432
# num_h_cluster_low_norm                   mean_h_cluster_high_oscore               -0.203002
# num_manual_realistic                     mean_originality_inverse_sum_similarity  0.186564
# num_requested                            num_manual_utility_normalized            -0.180240
# mean_word_count                          num_manual_underdefined                  -0.163366
# num_manual_underdefined                  mean_h_cluster_high_oscore               0.158388
# mean_word_count                          num_h_cluster_high_norm                  0.154047
# num_manual_realistic                     mean_h_cluster_low_oscore                0.150988
# num_manual_original_normalized           num_manual_underdefined                  -0.149344
# num_manual_utility_normalized            mean_originality_inverse_sum_similarity  -0.136722
# num_manual_original_normalized           num_h_cluster_low_norm                   0.122537
# num_manual_original_normalized           num_h_cluster_high_norm                  0.117960
# mean_manual_distance                     mean_h_cluster_low_oscore                0.112160
# num_manual_realistic                     num_h_cluster_high_norm                  -0.109394
# num_requested                            mean_h_cluster_high_oscore               0.105458
# num_h_cluster_high_norm                  mean_h_cluster_low_oscore                -0.102412
# num_h_cluster_low_norm                   mean_h_cluster_low_oscore                0.100675
# num_manual_original_normalized           num_manual_realistic                     0.090443
# num_manual_underdefined                  mean_h_cluster_low_oscore                -0.089709
# mean_originality_inverse_sum_similarity  num_h_cluster_high_norm                  0.078265
# num_manual_utility_normalized            num_manual_realistic                     -0.076415
# mean_manual_distance                     mean_originality_inverse_sum_similarity  0.067189
# num_manual_original_normalized           num_manual_utility_normalized            0.065136
# num_manual_realistic                     num_h_cluster_low_norm                   -0.063272
# num_manual_original_normalized           mean_manual_distance                     -0.063025
# num_manual_realistic                     num_manual_underdefined                  -0.055118
# mean_word_count                          mean_h_cluster_low_oscore                -0.053877
# mean_word_count                          mean_manual_distance                     -0.049372
# mean_word_count                          num_manual_original_normalized           0.049082
# num_requested                            mean_word_count                          -0.045454
# mean_manual_distance                     mean_h_cluster_high_oscore               -0.039164
# num_manual_utility_normalized            mean_h_cluster_high_oscore               0.021817
# mean_word_count                          num_manual_utility_normalized            -0.011793
# num_manual_underdefined                  mean_originality_inverse_sum_similarity  -0.009895
