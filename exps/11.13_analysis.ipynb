# %%
## All of this is GPL (https://www.gnu.org/licenses/gpl.html)

# %%
import pandas as pd
import scipy as sp
import numpy as np
import csv, os
import re
import scipy.stats as stats
import networkx as nx
#import cPickle as pickle
import itertools
from imp import reload
import random
import math

from collections import defaultdict, OrderedDict

# %% [markdown]
# # Introduction
#
# The plan is to read in a bunch of fields from our various data sources and then do some stats on them.
#
# Note that the first four fields together provide a unique way of identifying the answer (this could be better).
#
# ## Transform data
#
# For analysis, we may want to throw out some of it or manipulate things in some way. The following code block does this.

# %%
pystan_test_mode = False # When this variable is on, we do single chains and few iterations, to go fast
pystan_fit_cache = dict()

# %%
def all_pairings(s):
    return ((s1, s2) for i, s1 in enumerate(s[:-1])
                     for s2 in s[i+1:])

# %%
def filter_match_data_size(df):
    nr_conds = set(df['num_requested'])
    
    keep_indices = []
    
    for nr in nr_conds:
        sub_df = df[df['num_requested'] == nr]
        
        questions = sub_df.groupby('question_code')
        least_runs = min(len(qdf.groupby(['worker_id', 'accept_datetime', 'submit_datetime']))
                            for name, qdf in questions)
        
        for qc in set(sub_df['question_code']):
            ssub_df = sub_df[sub_df['question_code'] == qc]
            runs = list(ssub_df.groupby(['worker_id', 'accept_datetime', 'submit_datetime']))
            runs = random.sample(runs, least_runs)
            
            for ix, (name, run) in enumerate(runs):
                keep_indices.extend(run.index)
                
    new_df = df.select(lambda x: x in keep_indices)
    
    return new_df

def filter_repeats(df):
    new_df = df[df['is_repeat_worker'] == 0]
    return new_df

# A stupid function to just combine some filters. Oh, for haskell operators...
def filter_today(df):
    #df = df[df['question_code'] == 'iPod']
    df = df[df['question_code'] == 'turk']
    df = filter_repeats(df)
    #df = filter_match_data_size(df)
    return df

# %%
# Import data

import format_data
reload(format_data)

processed_data_folder = '/home/fil/enc_projects/crowbrain/processed_data'
idf, cfs = format_data.do_format_data(processed_data_folder, filter_today)
df, rmdf, clusters_df, cluster_forests = format_data.mk_redundant(idf, cfs)

print(len(idf), len(rmdf))
# Out:
# repeat worker check count 341
# 2075
#  56

# %%
  
# Have to filter these after, because they rely on tree structure
# TODO: add a post-tree structure filter section to the import data call

example = df[(df['answer'] == 'part out') | (df['answer'] == 'writing')]
st_roots = set(example['subtree_root'])

print("Number of random or underdefined responses:", len(df[df['subtree_root'].isin(st_roots)]))

df = df[~df['subtree_root'].isin(st_roots)]

print(len(df))
# Out:
# Number of random or underdefined responses: 44
# 2031

# %%
# match with runs
iPod_df = df[df['question_code'] == 'iPod']
print(len(iPod_df))
print(len(rmdf)) # TODO: getting fewer runs now. That's a problem
# Out:
# 3005
# 146

# %%
nr_conds = list(set(df['num_requested']))
nr_conds = sorted(nr_conds)
print(nr_conds)

qc_conds = list(set(df['question_code']))
print(qc_conds)

matplotlib_colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

qc_colors = {None: matplotlib_colors[0]}
for i, code in enumerate(qc_conds):
    qc_colors[code] = matplotlib_colors[i+1]
print(qc_colors)

nr_colors = {None: matplotlib_colors[0]}
for i, nr in enumerate(nr_conds):
    nr_colors[nr] = matplotlib_colors[i+1]
print(nr_colors)

cond_colors = {'question_code': qc_colors,
                'num_requested': nr_colors }
# Out:
# [5, 10, 20, 50, 75, 100]
# ['iPod']
# {None: 'b', 'iPod': 'g'}
# {50: 'm', 20: 'c', None: 'b', 100: 'k', 10: 'r', 75: 'y', 5: 'g'}

# %%
print(df)
print(clusters_df)

df.to_csv('ipython_output/instances.csv')
clusters_df.to_csv('ipython_output/trees.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3005 entries, 0 to 3016
# Data columns (total 45 columns):
# worker_id                 3005  non-null values
# question                  3005  non-null values
# question_code             3005  non-null values
# post_date                 3005  non-null values
# screenshot                3005  non-null values
# num_requested             3005  non-null values
# answer_num                3005  non-null values
# answer                    3005  non-null values
# word_count                3005  non-null values
# start_time                2983  non-null values
# end_time                  2983  non-null values
# answer_code               0  non-null values
# submit_datetime           3005  non-null values
# accept_datetime           3005  non-null values
# is_repeat_worker          3005  non-null values
# answer_id                 3005  non-null values
# idea                      3005  non-null values
# ...

# %% [markdown]
# # Graphing Functions
#
# These were getting long and generic, so put them where they can be safely ignored

# %%
def init_multifig(num_conditions, fignum = 1, subplot_size = (5.5, 5.5)):
    rows = None
    cols = None
    if subplot_size[0] <= 7:
        rows = math.ceil(num_conditions / float(2))
        cols = 2
    else:
        rows = num_conditions
        cols = 1
    return rows, cols, figure(fignum, figsize=(cols * subplot_size[0], rows * subplot_size[1]))

## Assumes the dataframe is sorted
def dec_plot_func_window(plot_func, window_size, field, order_field = None):
    """
    Slides a window across the data field and takes the mean within each window before plotting
    """
    
    def new_plot_func(a_df, ax, label=None, color = 'b'):
        new_order = []
        rolling_mean = []
        
        s = a_df[field] if order_field is None else a_df.sort(order_field)[field]
        
        for i in range(0, len(s) - window_size + 1):
            new_order.append(i + window_size/2)
            rolling_mean.append(np.mean(s.iloc[i : i +window_size]))
            
        new_df = pd.DataFrame({
                               'answer_num': pd.Series(new_order, dtype='uint32'),
                               field: pd.Series(rolling_mean),
                               })
        plot_func(new_df, ax, label, color)
        
    return new_plot_func

def dec_plot_func_window_by_order(plot_func, window_size, field):
    """
    Unlike window, this very problem-specific function windows each run
    separately. The results can be combined post-hoc
    """
    def new_plot_func(a_df, ax, label=None, color = 'b'):
        new_order = []
        rolling_mean = []
        
        max_answer_num = max(a_df['answer_num'])
        if max_answer_num < window_size:
            return
        
        groups = a_df.groupby(['worker_id', 'num_requested', 'question_code'])
        for name, group in groups:
            sortg = group.sort(['answer_num'])
            s = sortg[field]
            for i in range(0, len(s) - window_size + 1):
                rolling_mean.append(np.mean(s.iloc[i : i+window_size]))
                new_order.append(i + window_size/2)
        
        new_df = pd.DataFrame({
                               'answer_num': pd.Series(new_order, dtype='uint32'),
                               field: pd.Series(rolling_mean),
                               })
        
        plot_func(new_df, ax, label, color)
    
    return new_plot_func

def dec_plot_func_cross_cond(plot_func, condition, legend_loc='lower right',all_cond=False):
    """
    Plot all different values of the condition field on the same axes with a legend
    """
    def new_plot_func(a_df, ax, label = None, color='b'):
        cs = sorted(set(a_df[condition]))
        
        lsuffix = '-%s' % label if label else ''
        
        #overrides the color
        c_dict = cond_colors[condition]
        
        if all_cond:
            plot_func(a_df, ax, label='all' + lsuffix, color=c_dict[None])
        
        for c in cs:
            sub_df = a_df[a_df[condition] == c]
            plot_func(sub_df, ax, label=str(c) + lsuffix, color=c_dict[c])
        
        ax.legend(loc=legend_loc)
            
    return new_plot_func

def plot_pf(a_df, plot_func, xlab, ylab, color = 'b',
            plot_size = (5.5, 5.5), ylimits = None, xlimits = None):
    """
    Take a plot function and do a regular plotting of it in a single figure
    """
    rows, cols, fig = init_multifig(1, subplot_size = plot_size)
    
    ax = fig.add_subplot(rows, cols, 1)
    xlabel(xlab)
    ylabel(ylab)
    plot_func(a_df, ax, color = color)
              
    if ylimits is not None:
        ylim(ylimits[0], ylimits[1])
    if xlimits is not None:
        xlim(xlimits[0], xlimits[1])
    
    return ax

# plot_func should take a dataframe and some axes
def subplots_cross_cond(a_df, condition, xlab, ylab, plot_func,
                        subplot_size = (5.5, 5.5), ylimits = None, xlimits = None, all_cond = False):
    """
    Take a plot function and plot it in different subplots across a condition
    """
    cs = sorted(set(a_df[condition]))
    rows, cols, fig = init_multifig(len(cs) + (1 if all_cond else 0),
                                    subplot_size = subplot_size)
    
    c_dict = cond_colors[condition]
    
    if all_cond:
        ax = fig.add_subplot(rows, cols, 1)
        xlabel(xlab)
        ylabel(ylab)
        title('(all)')
        plot_func(a_df, ax, color=c_dict[None])
    
        if ylimits is not None:
            ylim(ylimits[0], ylimits[1])
            
        if xlimits is not None:
            xlim(xlimits[0], xlimits[1])
    
    for i, c in enumerate(sorted(cs)):
        sub_df = a_df[(a_df[condition] == c)]
        
        ax = fig.add_subplot(rows, cols, i + (2 if all_cond else 1))
        
        xlabel(xlab)
        ylabel(ylab)
        title('(%s)' % str(c))
        
        plot_func(sub_df, ax, color=c_dict[c])
        
        if ylimits is not None:
            ylim(ylimits[0], ylimits[1])
            
        if xlimits is not None:
            xlim(xlimits[0], xlimits[1])
        
    return fig

def dec_plot_func_cum_unique(plot_func, unique_field, pass_field = None, shuffles=1, order_name = 'answer_num'):
    """
    Transforms a plot function to plot a cumulative value instead of actual value.
    Shuffles the data to smooth if shuffles > 1
    """
    def new_plot_func(a_df, ax, label = None, color='b'):
        
        all_ys = np.zeros((len(a_df), shuffles))
        deep_copy = np.array([i for i in a_df.index])
        
        for i in range(shuffles):
            if shuffles > 1:
                np.random.shuffle(deep_copy)
            uniques = set()
            
            for j, ix in enumerate(deep_copy):
                u = a_df[unique_field][ix]
                if pass_field is None or a_df[pass_field][ix] > 0:
                    uniques.add(u)
                
                all_ys[j][i] = len(uniques)

        new_df = pd.DataFrame({
                               order_name: pd.Series(range(len(a_df)), dtype='uint32'),
                               unique_field: np.mean(all_ys, axis=1),
                               })

        plot_func(new_df, ax, label + '(cumulative)', color)
        
    return new_plot_func

def dec_plot_func_diff(plot_func, field):
    """
    Takes a plot function and transforms it to plot the differential of the field
    instead of the field itself
    """
    def new_plot_func(a_df, ax, label=None, color = 'b'):
        diffs = []
        new_order = []
        
        for i in range(1, len(a_df.index)):
            new_order.append(i)
            cur_index = a_df.index[i]
            last_index = a_df.index[i-1]
            
            f = a_df[field]
            diffs.append(f[cur_index] - f[last_index])
        
        new_df = pd.DataFrame({
                               'answer_num': pd.Series(new_order, dtype='uint32'),
                               field: pd.Series(diffs),
                               })
        
        plot_func(new_df, ax, label, color)
    
    return new_plot_func

def gen_basic_plot_func(yfield, xfield=None):
    def pf(a_df, ax, label = None, color = 'b'):
        ax.plot(a_df[xfield] if xfield is not None else range(len(a_df[yfield])),
                a_df[yfield], label=label, color=color)
        
    return pf

def gen_basic_hist_func(field, num_bins = 10, **kwargs):
    def pf(a_df, ax, label = None, color = 'b'):
        ax.hist(a_df[field], color=color, bins=num_bins, label=label, **kwargs)
    return pf

def gen_bar_err_func(field, group_field, pos_field = None, label_field = None, **kwargs):
    """
    Note: assumes that the order field and label field are uniform within groups
    """
    def pf(a_df, ax, label = None, color = 'b'):
        means = []
        stes = []
        poss = []
        labels = []
        
        groups = a_df.groupby([group_field])
        for i, (name, group) in enumerate(groups):
            poss.append(group[pos_field].iloc[0] if pos_field is not None else i)
            labels.append(group[label_field].iloc[0] if label_field is not None else name)
            means.append(np.mean(group[field]))
            stes.append(stats.sem(group[field], ddof=1) * 2)
        
        ax.bar(poss, means, yerr=stes, color = color, **kwargs)
        xticks(poss, labels)
    return pf

# TODO from here: need a filter transform that can be applied to each condition... might be a challenge
# Idea: rather than plotting everything, should the subplot/multiplot functions just provide a list
# of plot functions?

# plot_func should take a clusters dataframe and a label
def plot_idea_metric_cross_nr(a_df, a_cdf, plot_func):
    nrs = sorted(set(a_df['num_requested']))
    rows, cols, fig = init_multifig(len(nrs) + 1)

    ax = fig.add_subplot(rows, 2, 1)
    plot_func(a_cdf, ax, 'all')
    
    for j, nr in enumerate(nrs):
        sub_df = df[a_df['num_requested'] == nr]
        cs = set(sub_df['idea'])
        
        keep_indexes = [i for i in a_cdf.index if a_cdf['idea'][i] in cs]
        sub_cdf = a_cdf.loc[keep_indexes]
        
        ax = fig.add_subplot(rows, cols, 2 + j)
        plot_func(sub_cdf, ax, nr)

# %% [markdown]
# # Analysis functions

# %%
import subprocess

_hdi_stats_cache = {}
# Use this one instead
def get_hdi(a, b, confidence_interval):
  if (a,b,confidence_interval) in _hdi_stats_cache:
    return _hdi_stats_cache[(a,b,confidence_interval)]
  #print "get_hdi:", a, b, confidence_interval
  if a == 1 or b == 1:
    if a == 1 and b == 1:
      lower_bound = (1.0-confidence_interval) / 2
      upper_bound = 1.0 - lower_bound
    else:
      #print "special qbeta:", a, b, confidence_interval
      results = subprocess.check_output(["R", "-q", "-e", 'qbeta(%f, 1, %d)' % (confidence_interval, max(a,b))])
      results = str(results)
      results = results.split('\\n')[1]
      upper_bound = float(results[results.index(' ')+1:])
      if a < b:
        lower_bound = 0
      else:
        lower_bound = 1.0 - upper_bound
        upper_bound = 1.0
  else:
    results = subprocess.check_output(["R", "-q", "-e", 
        'get_hdi = function(a, b, level=0.95) { density_diff = function(lower, a, b) { p_lower = pbeta(lower, a, b); p_upper = min(1.0, p_lower + level); upper = qbeta(p_upper, a, b); return(dbeta(lower, a, b) - dbeta(upper, a, b)); }; lower = uniroot(density_diff, c(0, qbeta(1.0-level, a, b)), a=a, b=b)$root; upper = qbeta(pbeta(lower, a, b) + level, a, b); return(c(lower, upper)); }; get_hdi(%d, %d, %f)' % (a, b, confidence_interval)])
    results = str(results)
    results = results.split('\\n')[1]
    results = results[results.index(' ')+1:]
    lower_bound, upper_bound = [float(x) for x in results.split(' ')]
  _hdi_stats_cache[(a,b,confidence_interval)] = (lower_bound, upper_bound)
  return lower_bound, upper_bound

def calculate_posterior(num_successes, total_num):
  a_prior = 1
  b_prior = 1
  a_post = a_prior + num_successes
  b_post = b_prior + (total_num - num_successes)
  posterior_mean = a_post / float(total_num + a_prior + b_prior)
  posterior_variance = posterior_mean * (1.0-posterior_mean) / (1.0 + a_prior + b_prior + total_num)
#  old_lower_bound, old_upper_bound = run_qbeta(a_post, b_post, 0.95)
  lower_bound, upper_bound = get_hdi(a_post, b_post, 0.95)
  return posterior_mean, lower_bound, upper_bound#, old_lower_bound, old_upper_bound


# HPD calculation from biopy, copied under GPL. Using this purely
# because it is an existing implementation of a credible interval,
# and I don't know why I would choose HDI, etc over this
def hpd(data, level) :
  """ The Highest Posterior Density (credible) interval of data at level level.

  :param data: sequence of real values
  :param level: (0 < level < 1)
  """ 
  
  d = list(data)
  d.sort()

  nData = len(data)
  nIn = int(round(level * nData))
  if nIn < 2 :
    raise RuntimeError("not enough data")
  
  i = 0
  r = d[i+nIn-1] - d[i]
  for k in range(len(d) - (nIn - 1)) :
    rk = d[k+nIn-1] - d[k]
    if rk < r :
      r = rk
      i = k

  assert 0 <= i <= i+nIn-1 < len(d)
  
  return (d[i], d[i+nIn-1])

# %% [markdown]
# # Data management functions

# %%
def bool_df_measure(orig_df, pass_selection):
    ns = pd.Series([0 for i in orig_df.index], index=orig_df.index)
    for i in pass_selection.index:
        ns[i] = 1
    return ns

# %% [markdown]
# ## Worker analyis
#
# How many workers did we have? How many HITs did each complete? Did any repeat the same questions?

# %%
#groups = df_repeat.groupby(['worker_id', 'question_code', 'num_requested', 'submit_datetime'])

#n_runs = 0
#n_repeats = 0

#for name, run in groups:
#    n_runs += 1
#    if run['is_repeat_worker'].iloc[0] == 1:
#        n_repeats +=1
    
#print("Number of runs:", n_runs)
#print("Number of turkers:", len(set(df['worker_id'])))

#print("Total number of repeats:", n_repeats)

#for qc in qc_conds:
#    for nr in nr_conds:
#        sub_df = df_repeat[(df_repeat['question_code'] == qc) & (df_repeat['num_requested'] == nr)]
#        sub_nrdf = df[(df['question_code'] == qc) & (df['num_requested'] == nr)]
#        groups = sub_df.groupby(['worker_id', 'question_code', 'num_requested', 'submit_datetime'])
        
#        n_runs = 0
#        n_repeats = 0
        
#        for name, run in groups:
#            n_runs += 1
#            if run['is_repeat_worker'].iloc[0] == 1:
#                n_repeats +=1
    
#        print(qc, nr, "runs:", n_runs)
#        print(qc, nr, "unique:", len(set(sub_nrdf['worker_id'])))

# %% [markdown]
# ### Response/instance stats

# %%
if False:
    def response_stats(df, title):
        print(title, "total:", len(df))
        print(title, "non-repeat:", len(df[df['is_repeat_worker'] == 0]))
        
    response_stats(df, 'all')
    for qc in qc_conds:
        response_stats(df_repeat[df_repeat['question_code'] == qc], qc)

# %% [markdown]
# ## Conditions
#
# How many responses in each condition?

# %%
for (nr, qc), runs in rmdf.groupby(['num_requested', 'question_code']):
    
    print(len(runs), "runs in condition", qc, "/", nr)
    total_received = sum(runs['num_received'])
    print(total_received, "responses total")
# Out:
# 57 runs in condition iPod / 5
# 293 responses total
# 39 runs in condition iPod / 10
# 372 responses total
# 21 runs in condition iPod / 20
# 413 responses total
# 9 runs in condition iPod / 50
# 450 responses total
# 10 runs in condition iPod / 75
# 634 responses total
# 10 runs in condition iPod / 100
# 855 responses total

# %% [markdown]
# # Tree summary stats
#
# + number of subtrees

# %% [markdown]
# ## Forest visualization

# %%
if False:
    try:
        from networkx import graphviz_layout
    except ImportError:
        raise ImportError("This example needs Graphviz and either PyGraphviz or Pydot")
    
    for i, qc in enumerate(cluster_forests.keys()):
        plt.figure(i, figsize=(8,8))
        title(qc)
        
        G = cluster_forests[qc]
        
        # layout graphs with positions using graphviz neato
        pos=nx.graphviz_layout(G,prog="neato")
        # twopi, circo, neato,dot, sfdp.
        # color nodes the same in each connected subgraph
        G = nx.Graph(G)
        C=nx.connected_component_subgraphs(G)
        for g in C:
            c=[random.random()]*nx.number_of_nodes(g) # random color...
            nx.draw(g,
                 pos,
                 node_size=30,
                 node_color=c,
                 vmin=0.0,
                 vmax=1.0,
                 with_labels=False
                 )

# %%
print(cluster_forests.keys())

for qc in cluster_forests.keys():
    df_qc = df[df['question_code'] == qc]
    cdf_qc = clusters_df[clusters_df['question_code'] == qc]
    
    num_subtrees =  len(set(cdf_qc['subtree_root']))
    num_ns_subtrees = len(cdf_qc[(cdf_qc['is_root'] == 1) & (cdf_qc['num_children'] > 0)])
    
    print(qc, 'has', len(df_qc), 'instances')
    print(qc, 'has', len(set(df_qc['idea'])), 'ideas')
    print(qc, "has", num_subtrees, " subtrees")
    print(qc, "has", num_ns_subtrees, "non-singleton subtrees (", float(num_ns_subtrees)/num_subtrees, "%)")
# Out:
# dict_keys(['iPod'])
# iPod has 3005 instances
# iPod has 1220 ideas
# iPod has 336  subtrees
# iPod has 120 non-singleton subtrees ( 0.35714285714285715 %)

# %%
def quartiles(sorte):
        l = len(sorte)
        return (sorte[int(l/4)], sorte[int(2*l/4)], sorte[int(3*l/4)])
    
for qc in cluster_forests.keys():
    print("==== ", qc, " ====")
    sub_df = df[df['question_code'] == qc]
    cdf_qc = clusters_df[clusters_df['question_code'] == qc]
    
    ssub_df = sub_df
    trees = set(ssub_df['subtree_root'])
    nr = "all"
    print(nr, 'has', len(set(ssub_df['worker_id'])), 'HITs')
    print(nr, 'has', len(ssub_df), 'instances')
    print(nr, 'has', len(set(ssub_df['idea'])), 'ideas')
    print(nr, "has", len(set(ssub_df['subtree_root'])), " subtrees")
    print(nr, "has", len(set(ssub_df[(ssub_df['is_root'] == 1) & (ssub_df['num_children'] > 0)]['subtree_root'])),
          "non-singleton subtrees")
    
    # get all tree heights
    tree_heights = sorted([clusters_df[clusters_df['idea'] == idea].iloc[0]['height_in_subtree'] for idea in trees])
    tree_nodes = sorted([clusters_df[clusters_df['idea'] == idea].iloc[0]['num_nodes_under'] for idea in trees])
    tree_instances = sorted([clusters_df[clusters_df['idea'] == idea].iloc[0]['num_instances_under'] for idea in trees])
    print(nr, "max tree height", max(tree_heights) + 1)
    print(nr, "t height quartiles", quartiles(tree_heights))
    print(nr, "t node quartiles", quartiles(tree_nodes))
    print(nr, "t instance quartiles", quartiles(tree_instances))
    print("")
    
    for nr in nr_conds:
        ssub_df = sub_df[sub_df['num_requested']==nr]
        trees = set(ssub_df['subtree_root'])
        
        print(nr, 'has', len(set(ssub_df['worker_id'])), 'HITs')
        print(nr, 'has', len(ssub_df), 'instances')
        print(nr, 'has', len(set(ssub_df['idea'])), 'ideas')
        print(nr, "has", len(set(ssub_df['subtree_root'])), " subtrees")
        print(nr, "has", len(set(ssub_df[(ssub_df['is_root'] == 1) & (ssub_df['num_children'] > 0)]['subtree_root'])),
            "non-singleton subtrees")
        
        # get all tree heights
        tree_heights = sorted([clusters_df[clusters_df['idea'] == idea].iloc[0]['height_in_subtree'] for idea in trees])
        tree_nodes = sorted([clusters_df[clusters_df['idea'] == idea].iloc[0]['num_nodes_under'] for idea in trees])
        tree_instances = sorted([clusters_df[clusters_df['idea'] == idea].iloc[0]['num_instances_under'] for idea in trees])
        print(nr, "max tree height", max(tree_heights) + 1)
        print(nr, "t height quartiles", quartiles(tree_heights))
        print(nr, "t node quartiles", quartiles(tree_nodes))
        print(nr, "t instance quartiles", quartiles(tree_instances))
        print("")
# Out:
# ====  iPod  ====
# all has 146 HITs
# all has 3005 instances
# all has 1220 ideas
# all has 322  subtrees
# all has 92 non-singleton subtrees
# all
#  max tree height 5
# all t height quartiles (0, 0, 1)
# all t node quartiles (1, 1, 3)
# all t instance quartiles (1, 2, 6)
#
# 5 has 57 HITs
# 5 has 290 instances
# 5 has 170 ideas
# 5 has 75  subtrees
# 5 has 28 non-singleton subtrees
# 5
#  max tree height 5
# 5 t height quartiles (1, 1, 2)
# 5 t node quartiles (2, 5, 15)
# 5 t instance quartiles (3, 13, 45)
#
# 10 has 39 HITs
# 10 has 372 instances
# 10 has 203 ideas
# 10 has 79  subtrees
# 10 has 34 non-singleton subtrees
# 10
#  max tree height 5
# 10 t height quartiles (1, 1, 2)
# 10 t node quartiles (2, 5, 17)
# 10 t instance quartiles (4, 14, 45)
#
# 20 has 21 HITs
# 20 has 412 instances
# 20 has 258 ideas
# 20 has 92  subtrees
# 20 has 40 non-singleton subtrees
# 20
#  max tree height 5
# 20 t height quartiles (0, 1, 2)
# 20 t node quartiles (1, 4, 15)
# ...

# %% [markdown]
# + number of instances in each subtree

# %%
def hist_cross_qc(a_df, field, y_label, num_bins=10, subplot_size=(4,3), xlimits = None, ylimits= None):
    pf = gen_basic_hist_func(field, num_bins)
    subplots_cross_cond(a_df, 'question_code', field, y_label,
                        pf, subplot_size = subplot_size, xlimits=xlimits, ylimits=ylimits)
    
def hist_cross_nr(a_df, field, y_label, num_bins=10, subplot_size=(4,3), xlimits = None, ylimits= None):
    pf = gen_basic_hist_func(field, num_bins)
    subplots_cross_cond(a_df, 'num_requested', field, y_label,
                        pf, subplot_size = subplot_size, xlimits=xlimits, ylimits=ylimits)
        
sub_df = clusters_df[(clusters_df['is_root'] == 1) & (clusters_df['num_instances_under'] > 1)]
hist_cross_qc(sub_df, 'num_instances_under', 'number of subtrees', xlimits=(0,300), ylimits=(0,120))

# %%
sub_df = clusters_df[(clusters_df['is_root'] == 1) & (clusters_df['num_instances_under'] > 1)]
hist_cross_qc(sub_df, 'num_ideas_under', 'number of subtrees', xlimits=(0,45), ylimits=(0,120))

# %% [markdown]
# + number of nodes in each subtree

# %%
sub_df = clusters_df[(clusters_df['is_root'] == 1)]
hist_cross_qc(sub_df, 'num_nodes_under', 'number of subtrees', xlimits=(0,140), ylimits=(0,350))

# %% [markdown]
# + depth of subtree distribution

# %%
sub_df = clusters_df[(clusters_df['is_root'] == 1)]
hist_cross_qc(sub_df, 'height_in_subtree', 'number of subtrees', xlimits=(0,4), ylimits=(0,250))

# %%
#sub_df = clusters_df[(clusters_df['is_root'] == 1)]
#hist_cross_nr(sub_df, 'height_in_subtree', 'number of subtrees')

#def plot_func(a_cdf, ax, label, color = 'b'):
#    ax.hist(a_cdf['height_in_subtree'], color=color)
#    ylabel("number of subtrees")
#    xlabel("subtree depth")
#    title("(%s)" % str(label))

#roots_df = clusters_df[clusters_df['is_root'] == 1]
#plot_idea_metric_cross_nr(df, roots_df, plot_func)
#plot_idea_metric_cross_qc(df, roots_df, plot_func)

# %% [markdown]
# + parent-child relationships (degree)

# %%
sub_df = clusters_df[(clusters_df['num_children'] > 0)]
hist_cross_qc(sub_df, 'num_children', 'number of subtrees', xlimits=(0,70), ylimits=(0,220), num_bins = 30)

# %% [markdown]
# + mass of tree
#
# + parents - community-created vs manual

# %%
hist_cross_qc(clusters_df, 'num_instances_under', 'number of subtrees', xlimits=(0,300), ylimits=(0,1400), num_bins = 20)

# %%
# TODO: replace with histograms?

figure(1, figsize=(14, 6))

number_trees_w_mass = []
number_trees_w_unique_mass = []
sizes = []

roots_df = clusters_df[clusters_df['is_root'] == 1]

sizes = range(max(roots_df['num_instances_under']))

for i in sizes:
    sub_df = roots_df[roots_df['num_instances_under'] == i]
    number_trees_w_mass.append(len(sub_df))
    
    sub_df = roots_df[roots_df['num_nodes_under'] == i]
    number_trees_w_unique_mass.append(len(sub_df))
    
plot(sizes, number_trees_w_mass, label='number of ideas')
plot(sizes, number_trees_w_unique_mass, label='number of unique ideas')
xlim(0, 100)

xlabel('number of ideas')
ylabel('number of trees')

legend(loc='upper right')

# %% [markdown]
# Nodes created by us vs nodes created by the community

# %%
def parent_stats(df, label):
    p_df = df[df['num_children'] > 0]
    print("number of parent (", label, ") nodes:", len(p_df))
    
    c_p_df = p_df[p_df['num_instances'] > 0]
    print("number of community parent nodes:", len(c_p_df))
    
    a_p_df = p_df[p_df['num_instances'] == 0]
    print("number of artificial parent nodes:", len(a_p_df))
    
    print("% artificial:", float(len(a_p_df)) / len(c_p_df))

parent_stats(clusters_df, "all")
roots_w_height_g_one = clusters_df[(clusters_df['is_root'] == 1) & (clusters_df['height_in_subtree'] > 0)]
parent_stats(roots_w_height_g_one, "root parents with height > 0")

for qc in cluster_forests.keys():
    sub_df = clusters_df[clusters_df['question_code'] == qc]
    parent_stats(sub_df, qc)
# Out:
# number of parent ( all ) nodes: 256
# number of community parent nodes: 200
# number of artificial parent nodes: 56
# % artificial: 0.28
# number of parent ( root parents with height > 0 ) nodes: 120
# number of community parent nodes: 92
# number of artificial parent nodes: 28
# % artificial: 0.30434782608695654
# number of parent ( iPod ) nodes: 256
# number of community parent nodes: 200
# number of artificial parent nodes: 56
# % artificial: 0.28

# %% [markdown]
# ## Number of Clusters
#
# TODO: rewrite this code

# %%
def num_ideas(question_code):
    return len(clusters_df[clusters_df['question_code'] == qc])

vcdf = df[~df['idea'].isnull()]

for qc in qc_conds:
    sub_df = vcdf[vcdf['question_code'] == qc]
    if len(sub_df) == 0:
        continue
    
    print("Question code %s" % qc)
    print("\tNumber of instances:", len(sub_df))
    print("\tNumber of ideas given by turkers:", len(set(sub_df['idea'])))
    print('\tNumber of ideas including artificial:', num_ideas(qc))
    
    print("\tinstances per cluster", float(len(sub_df)) / num_ideas(qc))
    
    for nr in nr_conds:
        print("\t", nr)
        sub_df = vcdf[(vcdf['question_code'] == qc) & (vcdf['num_requested'] == nr)]
        print("\t\tNumber of instances:", len(sub_df))
        n_ideas = len(set(sub_df['idea']))
        
        uniques = 0
        for i in sub_df.index:
            idea = sub_df['idea'][i]
            if len(sub_df[sub_df['idea'] == idea]) == 1:
                uniques += 1
        
        print("\t\tNumber of ideas given by turkers:", n_ideas)
        print("\t\tNumber of unique (in-condition) ideas:", uniques)
        print("\t\t% unique:",float(uniques)/len(sub_df))

        
#bar_mean_err_cross_qc(rm_h_cluster_valid_df, 'percent_unique',
#                      '# unique ideas (low) (normalized)', '# unique (low) (normalized)')
# Out:
# Question code iPod
# 	Number of instances: 3005
# 	Number of ideas given by turkers: 1220
# 	Number of ideas including artificial: 1333
# 	instances per cluster 2.2543135783945987
# 	 5
# 		Number of instances: 290
# 		Number of ideas given by turkers:
#  170
# 		Number of unique (in-condition) ideas: 135
# 		% unique: 0.46551724137931033
# 	 10
# 		Number of instances: 372
# 		Number of ideas given by turkers:
#  203
# 		Number of unique (in-condition) ideas: 150
# 		% unique: 0.4032258064516129
# 	 20
# 		Number of instances: 412
# 		Number of ideas given by turkers:
#  258
# 		Number of unique (in-condition) ideas: 187
# 		% unique: 0.4538834951456311
# 	 50
# 		Number of instances: 449
# 		Number of ideas given by turkers:
#  310
# 		Number of unique (in-condition) ideas: 235
# 		% unique: 0.5233853006681515
# 	 75
# 		Number of instances: 630
# 		Number of ideas given by turkers:
#  442
# 		Number of unique (in-condition) ideas: 346
# 		% unique: 0.5492063492063493
# 	 100
# ...

# %% [markdown]
# ### Kinds of clusters

# %%
def plot_func(a_cdf, ax, label, color='b'):
    singleton = a_cdf[a_cdf['num_children'] == 0]
    non_singleton = a_cdf[a_cdf['num_children'] > 0]
    num_non_s_ideas = sum(non_singleton['num_instances_under'])
    
    ax.bar([0, 1, 2], [len(singleton), len(non_singleton), num_non_s_ideas], color='b')
    xticks([0, 1, 2], ['singleton', 'non-singleton', '# in non-singletons'])
    ylabel("number of")
    title("(%s)" % str(label))

roots_df = clusters_df[clusters_df['is_root'] == 1]
plot_idea_metric_cross_nr(df, roots_df, plot_func)

# %% [markdown]
# ### Number of unique subtrees

# %%
if False:
    vc_rmdf = rmdf[~rmdf['idea'].isnull()]
    vc_rmdf['pc_unique_subtrees'] = vc_rmdf['r_num_unique_subtrees'] / vc_rmdf['num_received']
    
    pf = gen_bar_err_func('pc_unique_subtrees', 'num_requested')
    # assignment to supress double print
    a = subplots_cross_cond(vc_rmdf, 'question_code', xlab = 'num_requested',
                        ylab = '% unique subtrees', plot_func=pf, ylimits=(0,1), all_cond=True)

# %%
if False:
    hist(vc_rmdf['pc_unique_subtrees'], bins = 20)
    xlabel('number of category trees identified (normalized)')
    ylabel('number of runs')
    xlim(0, 1)

# %% [markdown]
# ### Number of unique ideas

# %%
if False:
    vc_rmdf['pc_unique_ideas'] = vc_rmdf['r_num_unique_ideas'] / vc_rmdf['num_received']
    
    pf = gen_bar_err_func('pc_unique_ideas', 'num_requested')
    a = subplots_cross_cond(vc_rmdf, 'question_code', xlab = 'num_requested',
                        ylab = '% unique ideas', plot_func=pf, ylimits=(0.6,1), all_cond=True)

# %%
if False:
    hist(vc_rmdf['pc_unique_ideas'], bins = 10)
    xlabel('number of ideas identified (normalized)')
    ylabel('number of runs')
    xlim(0, 1)

# %% [markdown]
# # Zoomed-out stats

# %% [markdown]
# ## Originality

# %%
adf = df[~df['idea'].isnull()]

rows, cols, fig = init_multifig(2, subplot_size = (5.5, 5))
ax = fig.add_subplot(rows, cols, 1)
a2 = fig.add_subplot(rows, cols, 2)

series = []
series2 = []

for nr in nr_conds:
    nrdf = adf[adf['num_requested'] == nr]
    series.append(nrdf['idea_oscore'])
    series2.append(nrdf['subtree_oscore'])
    
ax.boxplot(series)
ax.set_xticklabels(nr_conds)
ax.set_xlabel("number requested condition")
ax.set_ylabel("idea o-score")
ax.set_title("idea o-score")

a2.boxplot(series2)
a2.set_xticklabels(nr_conds)
a2.set_xlabel("number requested condition")
a2.set_ylabel("category o-score")
a2.set_title("category o-score")

# %% [markdown]
# # Metrics over time
#
# ## Number of trees

# %%
def field_by_order_split_qc(df, unique_field, pass_field=None, ylimits = None, xlimits = None):
    pf = gen_basic_plot_func(unique_field)
    pf = dec_plot_func_cum_unique(pf, unique_field, pass_field, shuffles=100)
    pf = dec_plot_func_cross_cond(pf, 'num_requested', legend_loc='upper left')
    
    fig = subplots_cross_cond(df, 'question_code',
                        xlab = 'number of instances received',
                        ylab = 'unique %s if %s' % (unique_field, pass_field),
                        plot_func = pf,
                        subplot_size = (10,10),
                        ylimits = ylimits)
    
def field_by_order_split_nr(df, unique_field, pass_field=None, ylimits = None, xlimits = None):
    pf = gen_basic_plot_func(unique_field)
    pf = dec_plot_func_cum_unique(pf, unique_field, pass_field, shuffles=100)
    pf = dec_plot_func_cross_cond(pf, 'question_code', legend_loc='upper left')
    
    fig = subplots_cross_cond(df, 'num_requested',
                        xlab = 'number of instances received',
                        ylab = 'unique %s if %s' % (unique_field, pass_field),
                        plot_func = pf,
                        subplot_size = (6,6),
                        ylimits = ylimits,
                        all_cond = True)

# %%
vcdf = df[~df['idea'].isnull()]
field_by_order_split_nr(vcdf, 'subtree_root')

# %%
vcdf = df[~df['idea'].isnull()]
field_by_order_split_qc(vcdf, 'subtree_root')

# %% [markdown]
# ## Non-singleton Trees
#
# A non-singleton tree is a tree with at least one child node

# %%
vcdf = df[~df['idea'].isnull()]

passing = vcdf[(vcdf['is_root'] == 1) & (vcdf['num_children'] > 0)]
vcdf['non_singleton'] = bool_df_measure(vcdf, passing)
field_by_order_split_nr(vcdf, 'subtree_root', 'non_singleton')

# %%
field_by_order_split_qc(vcdf, 'subtree_root', 'non_singleton', ylimits=(0, 100))

# %% [markdown]
# ## Singleton trees

# %%
vcdf = df[~df['idea'].isnull()]
passing = vcdf[(vcdf['is_root'] == 1) & (vcdf['num_children'] == 0)]
vcdf['singleton'] = bool_df_measure(vcdf, passing)
field_by_order_split_nr(vcdf, 'subtree_root', 'singleton')

# %% [markdown]
# ### Singleton trees zoom

# %%
field_by_order_split_qc(vcdf, 'subtree_root', 'singleton', ylimits=(0, 60))

# %% [markdown]
# ## Number of ideas

# %%
vcdf = df[~df['idea'].isnull()]
field_by_order_split_qc(vcdf, 'idea')

# %% [markdown]
# # "Zoomed in" analysis
#
# Examining variables w.r.t. order in the response.
#
# ## Toolbox

# %%
def gen_plot_func_order(field, ylimits=None):
    def plot_func(a_df, ax, label = None, color = 'b'):
        sub_df = a_df.sort(columns=['answer_num'])
        
        groups = sub_df.groupby('answer_num')
        xs = [an for an, g in groups]
        means = [np.mean(g[field]) for an, g in groups]
        stes = [stats.sem(g[field], ddof=1) for an, g in groups]

        ax.errorbar(xs, means, yerr=stes, alpha=0.4, color=color, label=label)
        
        if ylimits is not None:
            ylim(ylimits[0], ylimits[1])
        
    return plot_func

def windowed_field_by_order_split_qc(field, window_size, ylimits = None, xlimits = None):
    pf = gen_plot_func_order(field)
    pf = dec_plot_func_window_by_order(pf, window_size, field)
    pf = dec_plot_func_cross_cond(pf, 'num_requested', legend_loc='upper right')
    
    vcdf = df[~df['idea'].isnull()]
    fig = subplots_cross_cond(vcdf, 'question_code',
                        xlab = 'answer_num',
                        ylab = '%s (windowed)' % field,
                        plot_func = pf,
                        subplot_size = (14,7),
                        ylimits = ylimits,
                        xlimits = xlimits)

def windowed_field_by_order_split_nr(field, window_size, ylimits = None, xlimits = None):
    pf = gen_plot_func_order(field)
    pf = dec_plot_func_window_by_order(pf, window_size, field)
    pf = dec_plot_func_cross_cond(pf, 'question_code', legend_loc='upper right')
    
    vcdf = df[~df['idea'].isnull()]
    fig = subplots_cross_cond(vcdf, 'num_requested',
                        xlab = 'answer_num',
                        ylab = '%s (windowed)' % field,
                        plot_func = pf,
                        subplot_size = (14,7),
                        ylimits = ylimits,
                        xlimits = xlimits,
                        all_cond = True)

# TODO looks like I still need a window by order decorator
# Basically I need to window one axis, but by groups (and then with a specific ordering within that group)
# There is probably a nicer, framework-adhering way to do this
# Idea for later: a split -> transform -> combine method (kind of a map-reduce)

# %% [markdown]
# ### idea_oscore

# %%
windowed_field_by_order_split_nr('idea_oscore', 10, ylimits = (0.993, 1), xlimits=(0,100))

# %%
sub_df = df[(df['question_code'] == 'iPod') & (df['num_requested'] == 100) & (~df['idea'].isnull())]
quarts = quartiles(sorted(sub_df['idea_oscore']))


pf = gen_plot_func_order('idea_oscore')
pf = dec_plot_func_window_by_order(pf, 10, 'idea_oscore')
#pf = dec_plot_func_cross_cond(pf, 'num_requested', legend_loc='upper right')
ax = plot_pf(sub_df, pf, 'answer_num', 'idea o-score', plot_size = (11, 3.5))

ax.plot([0, 100], [quarts[0], quarts[0]])
ax.text(2, quarts[0] - 0.0003, "first quartile")

ax.plot([0, 100], [quarts[1], quarts[1]])
ax.text(2, quarts[1] - 0.0003, "second quartile")

ax.plot([0, 100], [quarts[2], quarts[2]])
ax.text(2, quarts[2] - 0.0003, "third quartile")
title('idea o-score for 100 condition')

# %%
sub_df = df[(df['question_code'] == 'iPod') & (~df['idea'].isnull())]
pf = gen_plot_func_order('idea_oscore')
pf = dec_plot_func_window_by_order(pf, 10, 'idea_oscore')
#pf = dec_plot_func_cross_cond(pf, 'num_requested', legend_loc='upper right')
ax = plot_pf(sub_df, pf, 'answer_num', 'idea o-score', plot_size = (11, 3.5))

# %%
sub_df = df[(df['question_code'] == 'iPod') & (df['num_requested'] == 100) & (~df['idea'].isnull())]
quarts =  quartiles(sorted(sub_df['subtree_oscore']))

pf = gen_plot_func_order('subtree_oscore')
pf = dec_plot_func_window_by_order(pf, 10, 'subtree_oscore')
#pf = dec_plot_func_cross_cond(pf, 'num_requested', legend_loc='upper right')
ax = plot_pf(sub_df, pf, 'answer_num', 'category o-score', plot_size = (11, 3.5))

ax.plot([0, 100], [quarts[0], quarts[0]])
ax.text(2, quarts[0] - 0.002, "first quartile")

ax.plot([0, 100], [quarts[1], quarts[1]])
ax.text(2, quarts[1] - 0.002, "second quartile")

ax.plot([0, 100], [quarts[2], quarts[2]])
ax.text(2, quarts[2] - 0.002, "third quartile")
title('category o-score for 100 condition')

# %%
sub_df = df[(df['question_code'] == 'iPod') & (~df['idea'].isnull())]
pf = gen_plot_func_order('subtree_oscore')
pf = dec_plot_func_window_by_order(pf, 10, 'subtree_oscore')
#pf = dec_plot_func_cross_cond(pf, 'num_requested', legend_loc='upper right')
ax = plot_pf(sub_df, pf, 'answer_num', 'category o-score', plot_size = (11, 3.5))

# %% [markdown]
# ### subtree_oscore

# %%
windowed_field_by_order_split_nr('subtree_oscore', 10, ylimits = (0.93, 0.995), xlimits=(0,100))

# %%
windowed_field_by_order_split_qc('subtree_oscore', 5, ylimits = (0.92, 1))

# %%
windowed_field_by_order_split_nr('is_inmix', 5)

# %%
windowed_field_by_order_split_qc('is_inmix', 5)

# %% [markdown]
# ### is_midmix

# %%
windowed_field_by_order_split_nr('is_midmix', 10)

# %%
windowed_field_by_order_split_qc('is_midmix', 5)

# %% [markdown]
# ### time_spent

# %%
windowed_field_by_order_split_qc('time_spent', 5, ylimits = (0, 600000))

# %% [markdown]
# # Remixing/Riffing

# %% [markdown]
# ## Summary stats

# %%
adf = df[~df['idea'].isnull()]

for qc in cluster_forests.keys():
    sub_adf = adf[adf['question_code'] == qc]
    
    for nr in nr_conds:
        print("================", qc, "==================")
        nrdf = sub_adf[sub_adf['num_requested'] == nr]
        
        om = nrdf[nrdf['is_outmix'] == 1]
        im = nrdf[nrdf['is_inmix'] == 1]
        
        if len(im) == 0:
            continue
        
        mm = nrdf[nrdf['is_midmix'] == 1]
        dist_sim = nrdf[~(nrdf['distance_from_similar']).isnull()]['distance_from_similar']
        dist_inmix = nrdf[~(nrdf['distance_from_inmix']).isnull()]['distance_from_inmix']
        
        pc_riffs = float(len(om)) / len(nrdf)
        pc_inmixes = float(len(im)) / len(nrdf)
        pc_mmixes = float(len(mm)) / len(nrdf)
        riffs_per_inmix = float(len(om)) / float(len(im))
        
        print(nr, "% outmixes", pc_riffs)
        print(nr, "% inmixes", pc_inmixes)
        print(nr, "% midmixes", pc_mmixes)
        print(nr, "riffs per inmix", riffs_per_inmix)
        print(nr, "mean distance from similar", np.mean(dist_sim))
        print(nr, "median distance from similar", np.median(dist_sim))
        print(nr, "mean distance from inmix", np.mean(dist_inmix))
        print(nr, "median distance from inmix", np.median(dist_inmix))
        print("")
# Out:
# ================ iPod ==================
# 5 % outmixes 0.13448275862068965
# 5 % inmixes 0.10344827586206896
# 5 % midmixes 0.1310344827586207
# 5 riffs per inmix 1.3
# 5 mean distance from similar 1.6923076923076923
# 5 median distance from similar 1.0
# 5 mean distance from inmix 2.0256410256410255
# 5 median distance from inmix 2.0
#
# ================ iPod ==================
# 10 % outmixes 0.16666666666666666
# 10 % inmixes 0.13172043010752688
# 10 % midmixes 0.16666666666666666
# 10 riffs per inmix 1.2653061224489797
# 10 mean distance from similar 3.0
# 10 median distance from similar 2.0
# 10 mean distance from inmix 3.435483870967742
# 10 median distance from inmix 3.0
#
# ================ iPod ==================
# 20 % outmixes 0.26941747572815533
# 20 % inmixes 0.15048543689320387
# 20 % midmixes 0.24271844660194175
# 20 riffs per inmix 1.7903225806451613
# 20 mean distance from similar 4.207207207207207
# 20 median distance from similar 2.0
# ...

# %% [markdown]
# ## Number of riffs/outmixes

# %%
def bar_mean_err_cross_qc(a_df, field, title, y_title, ylimits = (0,1)):
    pf = gen_bar_err_func(field, 'num_requested')
    subplots_cross_cond(a_df, 'question_code', 'num_requested', y_title, pf, all_cond = True, ylimits=ylimits)

if False:
    vc_rmdf = rmdf[rmdf['r_valid_cluster'] > 0]
    vc_rmdf['percent_outmix'] = vc_rmdf['num_outmix'] / vc_rmdf['num_received']
    
    bar_mean_err_cross_qc(vc_rmdf, 'percent_outmix',
                          '% outmix ideas', '% outmix ideas')

# %%
if False:
    vc_rmdf['percent_inmix'] = vc_rmdf['num_inmix'] / vc_rmdf['num_received']
    
    bar_mean_err_cross_qc(vc_rmdf, 'percent_inmix',
                          '% inmix ideas', '% inmix ideas')

# %% [markdown]
# ### Number of times an inmix is riffed upon

# %%
hist(df['inmix_index'].value_counts(), bins = 20)
xlim(0, 20)
xlabel("number of times remixed")
ylabel("number of inmixes")

# %% [markdown]
# ### lengths of remix chains

# %%
sub_df = df[(~df['idea'].isnull())]
runs = sub_df.groupby(['worker_id', 'submit_datetime', 'num_requested', 'question_code'])

run_lengths = defaultdict(list)

for (wid, sdt, nr, qc), run in runs:
    cur_length = 0
    start_im = None
    run = run.sort('answer_num')
    for i in run.index:
        iom = run['is_outmix'][i]
        sim = run['inmix_index'][i]
        
        if iom > 0:
            if start_im is None or start_im == sim:
                cur_length += 1
            else:
                cur_length = 1
            start_im = sim
        elif cur_length > 0:
            if cur_length > 1:
                run_lengths[nr].append(cur_length)
            cur_length = 0
            start_im= None

rows, cols, fig = init_multifig(len(nr_conds), subplot_size=(4,4))
for i, nr in enumerate(nr_conds):
    
    if not nr in run_lengths:
        continue
    
    subplot(rows, cols, i + 1)
    hist(run_lengths[nr])
    title(str(nr))
    xlim(0, 8)
    xlabel("remix run length")
    ylabel("number of remixes of length")
    ylim(0, 25)
    
    print(nr, "number of riff chains", len(run_lengths[nr])) # TODO: normalize in some way
    print(nr, "max riff chain", max(run_lengths[nr]))
    print(nr, "median riff chain", np.median(run_lengths[nr]))
    print("")
# Out:
# 5 number of riff chains 2
# 5 max riff chain 2
# 5 median riff chain 2.0
#
# 10
#  number of riff chains 4
# 10 max riff chain 2
# 10 median riff chain 2.0
#
# 20
#  number of riff chains 11
# 20 max riff chain 4
# 20 median riff chain 2.0
#
# 50
#  number of riff chains 16
# 50 max riff chain 4
# 50 median riff chain 2.0
#
# 75
#  number of riff chains 11
# 75 max riff chain 4
# 75 median riff chain 2.0
#
# 100
#  number of riff chains 35
# 100 max riff chain 6
# 100 median riff chain 2.0

# %% [markdown]
# ## O-score originality based on heirarchical clustering

# %%
bar_mean_err_cross_qc(vcdf, 'subtree_oscore',
                      'subtree oscore', 'subtree oscore', ylimits=(0.94,1))

# %%
bar_mean_err_cross_qc(vcdf, 'idea_oscore',
                      'idea oscore', 'idea oscore', ylimits=(0.992,1))

# %%
hist(vcdf['idea_oscore'], bins=1000)
xlim(0.992, 1)
# Out:
# (0.992, 1)

# %% [markdown]
# ## time spent

# %%
tcdf = df[~df['time_spent'].isnull()]

bar_mean_err_cross_qc(tcdf, 'time_spent',
                      'time spent per answer', 'time spent per answer', ylimits=(0,700000))

# %%
vtdf = df[~df['time_spent'].isnull()]

filtered_times = [i for i in vtdf['time_spent'] if i < 100000]

hist(filtered_times, bins=100)
# Out:
# (array([ 15.,  38.,  81.,  76.,  89.,  85.,  98.,  89.,  89.,  84.,  89.,
#         87.,  74.,  73.,  72.,  74.,  73.,  51.,  55.,  58.,  52.,  36.,
#         42.,  40.,  39.,  40.,  45.,  26.,  20.,  35.,  36.,  36.,  18.,
#         22.,  24.,  28.,  31.,  24.,  22.,  20.,  22.,  27.,  16.,  12.,
#         21.,  14.,  22.,  17.,  15.,  16.,   9.,  17.,  12.,  10.,  11.,
#          8.,  12.,  12.,  10.,   5.,  10.,  11.,   7.,   8.,  10.,  11.,
#          7.,  13.,   4.,   7.,   7.,   8.,   6.,   8.,   3.,  11.,   7.,
#          6.,   1.,   8.,   9.,  11.,   6.,   8.,   3.,   4.,   5.,   6.,
#          6.,   5.,   1.,   8.,   4.,   4.,   3.,   7.,   5.,   5.,   6.,
#          1.]),
#  array([  1445.  ,   2429.61,   3414.22,   4398.83,   5383.44,   6368.05,
#          7352.66,   8337.27,   9321.88,  10306.49,  11291.1 ,  12275.71,
#         13260.32,  14244.93,  15229.54,  16214.15,  17198.76,  18183.37,
#         19167.98,  20152.59,  21137.2 ,  22121.81,  23106.42,  24091.03,
# ...

# %% [markdown]
# # Modelling
#
# Now that Pystan exists, we can do modelling right in the notebook! Dreamy!
#
# Note: when running this notebook the first time, it's recommended to "run all" above here to get the data set up and make all the plots of "cheap" descriptive stats. Below, run blocks under headings as-needed, as each is a hypothesis test that relies on MCMC methods, which can be slow.

# %% [markdown]
# ## Model rate of idea/category generation
#
# Take cumulative counts of these in each condition.

# %%
import pystan

exp_model_string = """
data {
    int N; // number of instances
    real y[N]; // the number of ideas or categories receieved up to and including instance n
    int x[N]; // ordinal position of the instance in its condition
    int num_cond; // the number of conditions
    int cond_group[N]; // which condition
}

parameters {
    real<lower=0, upper=1> b_cond[num_cond];
    real<lower=0> y_scale;
    real<lower=0> sigma;
}

model {
    real mu[N];
    for (i in 1:N) {
        mu[i] <- y_scale * pow(x[i], b_cond[cond_group[i]]);
        y[i] ~ normal(mu[i], sigma);
    }
}
"""

def gen_exp_model_data(df, field):
    dat = defaultdict(list)

    for condition_num, nr in enumerate(nr_conds):
        nrdf = df[df['num_requested'] == nr]
        for qc in cluster_forests.keys():
            qcdf = nrdf[nrdf['question_code'] == qc]
            qcdf = qcdf.sort(columns=['submit_datetime', 'answer_num'], ascending=[1, 1])
            uniques = set()
            
            for order, thing in enumerate(qcdf[field]):
                uniques.add(thing)
                
                dat['x'].append(order + 1)
                dat['y'].append(len(uniques))
                dat['cond_group'].append(condition_num + 1)
                
    dat['N'] = len(dat['x'])
    dat['num_cond'] = len(nr_conds)
    
    return dat

def add_hpd_bar(ax, left, right, label, index):
    h = 200 + 100 * index
    ax.plot([left, right], [h, h], color='k')
    ax.plot([left, left], [h + 50, h - 50], color='k')
    ax.plot([right, right], [h + 50, h - 50], color='k')

def exp_model_density_regions(dat, fit):
    la = fit.extract(permuted=True)
    b_conds = la['b_cond']
    
    regions = []
    for i in range(1, dat['num_cond'] + 1):
        b_cond_i_samples = b_conds[:, i - 1]
        m_bci = mean(b_cond_i_samples)
        
        regions.append(hpd(b_cond_i_samples, 0.95))
        
    return regions
    
def view_exp_model_fit(dat, fit):
    la = fit.extract(permuted=True)
    b_conds = la['b_cond']
    y_scales = la['y_scale']
    
    m_y_scale = np.mean(y_scales)
    
    # plot learned functions
    figure(figsize=(10,10))
    ax = subplot(1,1,1)
    xlim(0, 1000)
    ylim(0, 1000)
    legend()
    for i in range(1, dat['num_cond'] + 1):
        b_cond_i_samples = b_conds[:, i - 1]
        m_bci = mean(b_cond_i_samples)
        
        X = np.linspace(0, max(dat['x']), 500, endpoint=True)
        Y = [m_y_scale * pow(x, m_bci) for x in X]
        ax.plot(X, Y, label='condition %d' % i)
        #hist(b_cond_i_samples
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels)
    
    # plot parameters with HDI
    f = figure(figsize=(10,5))
    ax = f.add_subplot(1,1,1)
    density_regions = exp_model_density_regions(dat, fit)
    for i in range(1, dat['num_cond'] + 1):
        left, right = density_regions[i - 1]
        
        ax.hist(b_cond_i_samples, bins=20,
                label='condition %d' % i, alpha=0.2)
        add_hpd_bar(ax, left, right, 'condition %d hpd' % i, i)
        
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels)
    f.show()

# %%
def hyp_test(dats, model_string, testfunc, cache_key):
    n_chain = 1 if pystan_test_mode else 3
    n_saved_steps = 100 if pystan_test_mode else 10000
    
    fits = []
    for i, dat in enumerate(dats):
        ck = cache_key + str(i)
        if ck not in pystan_fit_cache:
            fit = pystan.stan(model_code=model_string,
                              data=dat,
                              iter=math.ceil(n_saved_steps/n_chain), chains=n_chain)
            pystan_fit_cache[ck] = fit
            fits.append(fit)
        else:
            fits.append(pystan_fit_cache[ck])
        
    success = testfunc(fits)
    return fits, success


def hyp_test_rate_exclude_one(df, field, cache_key):
    dat = gen_exp_model_data(df, field)
    
    def testfunc(fits):
        density_regions = exp_model_density_regions(dat, fits[0])
        return all([1 > right for left, right in density_regions])
    
    fits, success = hyp_test([dat], exp_model_string, testfunc, cache_key)
    return dat, fits, success

# %% [markdown]
# ### idea - data and run model

# %%
dat, fits, success = hyp_test_rate_exclude_one(df, 'idea', 'idea rate model')

print("Idea rate test: %s" % success)
# Out:
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# Idea rate test: True

# %% [markdown]
# ### idea - examine model

# %%
view_exp_model_fit(dat, fits[0])

# %% [markdown]
# ### category - run and view model

# %%
dat, fit, success = hyp_test_rate_exclude_one(df, 'subtree_oscore', 'category rate model')

print("Category rate test: %s" % success)
# Out:
# Category rate test: True

# %%
view_exp_model_fit(dat, fits[0])

# %% [markdown]
# ## Modelling idea/category rate with no conditions
#
# Due to convergence issues with models including conditions and individual parameters, we also build a model that simple fits a single model to all data and test that the HDI of the rate parameter does not include 1.

# %%
import pystan
from random import shuffle

exp_model_nocond_string = """
data {
    int N; // number of instances
    real y[N]; // the number of ideas or categories receieved up to and including instance n
    int x[N]; // ordinal position of the instance in its condition
}

parameters {
    real<lower=0, upper=1> rate;
    real<lower=0> y_scale;
    real<lower=0> sigma;
}

model {
    real mu[N];
    for (i in 1:N) {
        mu[i] <- y_scale * pow(x[i], rate);
        y[i] ~ normal(mu[i], sigma);
    }
}
"""

def gen_exp_model_nocond_data(df, field):
    dat = defaultdict(list)

    for condition_num, nr in enumerate(nr_conds):
        nrdf = df[df['num_requested'] == nr]
        for qc in cluster_forests.keys():
            qcdf = nrdf[nrdf['question_code'] == qc]
            qcdf = qcdf.sort(columns=['submit_datetime', 'answer_num'], ascending=[1, 1])
            uniques = set()
            
            for order, thing in enumerate(qcdf[field]):
                uniques.add(thing)
                
                dat['x'].append(order + 1)
                dat['y'].append(len(uniques))
                
    dat['N'] = len(dat['x'])
    
    return dat

def gen_exp_model_nocond_k_fold_data(field, k = 10):
    runs = df.groupby(['worker_id', 'num_requested'])
    
    run_dfs = [rdf for name, rdf in runs]
    
    shuffle(run_dfs)
    
    dats = []
    for i in range(k):
        train_df = pd.concat([rdf for j, rdf in enumerate(run_dfs) if j % k != i])
        test_df = pd.concat([rdf for j, rdf in enumerate(run_dfs) if j % k == i])
        
        train_dat = gen_exp_model_nocond_data(field, train_df)
        test_dat = gen_exp_model_nocond_data(field, test_df)
        #print(len(train_dat['x']), len(test_dat['x']))
    
        dats.append((train_dat, test_dat))
        
    return dats

def view_exp_model_nocond_fit(dat, fit):
    la = fit.extract(permuted=True)
    rates = la['rate']
    
    #print(rates)
    left, right = hpd(rates, 0.95)
    print(left, right)
    
def hyp_test_rate_nocond_exclude_one(df, field, cache_key):
    dat = gen_exp_model_nocond_data(df, field)
    
    def testfunc(fits):
        la = fits[0].extract(permuted=True)
        rates = la['rate']
        left, right = hpd(rates, 0.95)
        return 1 > right
    
    fits, success = hyp_test([dat], exp_model_nocond_string, testfunc, cache_key)
    return dat, fits, success

# %% [markdown]
# ### idea model

# %%
dat, fits, success = hyp_test_rate_nocond_exclude_one(df, 'idea', 'idea rate nocond test')

print("Idea rate nocond pass: %s" % success)
# Out:
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# Idea rate nocond pass: True

# %%
view_exp_model_nocond_fit(dat, fits[0])
# Out:
# 0.879825881792 0.890403770431

# %% [markdown]
# ### CHI 2013 requested k-fold cross validation

# %%
if False:
    # k-fold cross validated
    
    total_mse = 0
    total_rse = 0
    
    fits = []
    
    k = 3
    
    for train_dat, test_dat in gen_exp_model_nocond_k_fold_data('idea', k):
        #n_chain = 3;
        #n_saved_steps = 10000;
        
        n_chain = 2;
        n_saved_steps = 10000;
        idea_fit = pystan.stan(model_code=exp_model_nocond_string,
                      data=train_dat,
                      iter=math.ceil(n_saved_steps/n_chain), chains=n_chain)
        
        y_scale = np.mean(idea_fit.extract(permuted=True)['y_scale'])
        rate = np.mean(idea_fit.extract(permuted=True)['rate'])
        
        def estimate(x):
            return y_scale * pow(x, rate)
        
        res = [pow(estimate(x) - y, 2) for x, y in zip(train_dat['x'], train_dat['y'])]
        mre = np.mean(res)
        print("residual error", mre)
        
        ses = [pow(estimate(x) - y, 2) for x, y in zip(test_dat['x'], test_dat['y'])]
        mse = np.mean(ses)
        print("test error", mse)
        
        #break
        
        total_mse += mse
        total_rse += mre
        
        fits.append(idea_fit)

# %%
if False:
    print(total_mse / k)
    print(total_rse / k)
    
    for fit in fits:
        y_scales = fit.extract(permuted=True)['y_scale']
        rate = fit.extract(permuted=True)['rate']
        
        print(hpd(y_scales, 0.95))
        print(hpd(rate, 0.95))

# %% [markdown]
# ### Category model

# %%
dat, fits, success = hyp_test_rate_nocond_exclude_one(df, 'subtree_root', 'category rate nocond test')

print("Category rate nocond pass: %s" % success)
# Out:
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# Category rate nocond pass: True

# %%
view_exp_model_nocond_fit(dat, fits[0])
# Out:
# 0.662740109829 0.67877589429

# %% [markdown]
# ## Early Common Analysis
#
# One hypothesis in the paper is that there are a set of common, general ideas that make up the first several responses of each session. To test this, we take a set of the 5% of most common ideas. Then we test the probability that an idea in the first 5 instances of a run is in the common set, and the probability an idea in any later section of the run is in the common set.
#
# We only train these parameters on runs that have 10 or more responses, so no run can contribute to either parameter without contributing to the other.

# %%
def hyp_test_early_common(df, clusters_df):
    temp_df = clusters_df.sort('num_instances_under', ascending=False)
    num_top_5_pc = math.ceil(len(temp_df) * 0.05)
    top_5_pc = temp_df.iloc[:num_top_5_pc]
    top_5_pc_idea = set(top_5_pc['idea'])
    
    ten_or_more = df[df['num_received'] >= 10]
    first_five = ten_or_more[ten_or_more['answer_num'] < 5]
    rest = ten_or_more[ten_or_more['answer_num'] >= 5]
    
    first_five_successes = len([idea for idea in first_five['idea'] if idea in top_5_pc_idea])
    rest_successes = len([idea for idea in rest['idea'] if idea in top_5_pc_idea])
    
    first_five_post = calculate_posterior(first_five_successes, len(first_five))
    rest_post = calculate_posterior(rest_successes, len(rest))
    
    return first_five_post, rest_post, min(first_five_post) > max(rest_post)

# %%
print(hyp_test_early_common(df, clusters_df))
# Out:
# ((0.5044843049327354, 0.4581752, 0.5508307), (0.23645970937912814, 0.2190452, 0.2539783), True)

# %% [markdown]
# ## Originality before/after 20

# %%
beta_model = """
data {
    int N;
    real y[N];
}

parameters {
    real<lower=0> alpha;
    real<lower=0> beta;
}

model {
    for (i in 1:N) {
        y[i] ~ beta(alpha, beta);
    }
}
"""


def split_20_beta_model_dat(df, field):
    left_df = df[df['answer_num'] < 20]
    right_df = df[df['answer_num'] >= 20]
    
    left_dat = { 'N': len(left_df),
                 'y': left_df[field] }
    right_dat = { 'N': len(right_df),
                  'y': right_df[field] }
    
    return left_dat, right_dat

def view_split_20_beta_model_fit(left_fit, right_fit):
    for name, fit in [('LEFT', left_fit), ('RIGHT', right_fit)]:
        la = fit.extract(permuted=True)
        alpha = la['alpha']
        beta = la['beta']
        
        print(name)
        hl, hr = hpd(alpha, 0.95)
        print("alpha:", hl, hr)
        hl, hr = hpd(beta, 0.95)
        print("beta:", hl, hr)
        
def hyp_test_split_20_beta_model(df, field, cache_key):
    dats = list(split_20_beta_model_dat(df, field))
    
    def testfunc(fits):
        prev_alpha = None
        prev_beta = None
        for name, fit in [('LEFT', fits[0]), ('RIGHT', fits[1])]:
            la = fit.extract(permuted=True)
            alpha = la['alpha']
            beta = la['beta']
            
            if prev_alpha is None:
                prev_alpha = hpd(alpha, 0.95)
                prev_beta = hpd(beta, 0.95)
            else:
                alpha = hpd(alpha, 0.95)
                beta = hpd(beta, 0.95)
                if max(prev_alpha) < min(alpha) or max(alpha) < min(prev_alpha):
                    return True
                elif max(prev_beta) < min(beta) or max(beta) < min(prev_beta):
                    return True
        return False
    
    fits, success = hyp_test(dats, beta_model, testfunc, cache_key)
    
    return dat, fits, success

# %% [markdown]
# ### idea o-score

# %%
dat, fits, success = hyp_test_split_20_beta_model(df, 'idea_oscore', 'idea oscore split 20')

print("idea oscore split 20 pass: %s" % success)
# Out:
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# idea oscore split 20 pass: True

# %%
view_split_20_beta_model_fit(fits[0], fits[1])
# Out:
# LEFT
# alpha: 134.515300084 157.133006849
# beta: 0.681911943889 0.762053737704
# RIGHT
# alpha: 328.896707051 391.609754569
# beta: 0.767859444079 0.873870503156

# %% [markdown]
# ### Category o-score

# %%
dat, fits, success = hyp_test_split_20_beta_model(df, 'subtree_oscore', 'cat oscore split 20')

print("cat oscore split 20 pass: %s" % success)
# Out:
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# cat oscore split 20 pass: True

# %%
view_split_20_beta_model_fit(fits[0], fits[1])
# Out:
# LEFT
# alpha: 39.4087813062 45.8134773594
# beta: 1.01451477814 1.14336647116
# RIGHT
# alpha: 38.8682456879 46.1069480357
# beta: 0.726091153004 0.820879230149

# %% [markdown]
# ## Same tests as above, but with Mann-Whitney U non-parametric
#
# Recommended by a paper reviewer

# %%
from scipy.stats import mannwhitneyu
from random import sample

def test(s1, s2):
    """
    Samples to ensure the lengths of s1 and s2 are equal
    """
    
    N = min(len(s1), len(s2))
    s1p = sample(s1, N)
    s2p = sample(s2, N)
    
    print(len(s1p))
    print(sum(range(1,1360*2)))
    
    return mannwhitneyu(s1p, s2p)

print(test(list(idea_dat_l['y']), list(idea_dat_r['y'])))
print(test(list(cat_dat_l['y']), list(cat_dat_r['y'])))
# Out:
# 1360
# 3697840
# (675524.5, 3.6195031667821444e-35)
# 1360
# 3697840
# (709910.0, 4.3855135874827704e-26)

# %% [markdown]
# ## Probability of remaining in same category
#
# From the SIAM model, we hypothesize that an idea is more likely to be followed by another idea in the same category than by random change.

# %%
def hyp_test_prob_in_category(df):
    runs = df.groupby(['worker_id', 'num_requested', 'accept_datetime'])
    
    total_transitions = 0
    within_transitions = 0
    
    for name, run in runs:
        sorted_ideas = run.sort('answer_num', ascending=True)['subtree_root']
        pairs = list(zip(sorted_ideas[:-1], sorted_ideas[1:]))
        total_transitions += len(pairs)
        within_transitions += sum(1 for a, b in pairs if a == b)
    
    post = calculate_posterior(within_transitions, total_transitions)
    success = min(post) > max(df['idea_probability'])
    
    return post, success

# %%
post, success = hyp_test_prob_in_category(df)

print("Remain in category hypothesis pass: %s" % success)
print(post)
# Out:
# Remain in category hypothesis pass: True
# (0.15554002097168823, 0.1423607, 0.168904)

# %% [markdown]
# ## Time spent changing categories
#
# Also from SIAM, we expect time spent changing categories to be greater than time spent within categories. Both seem to fit a roughly log-normal distribution.

# %%
lognormal_time_model = """
data {
    int N;
    int y[N];
}

parameters {
    real<lower=1> mu;
    real<lower=1> sigma;
}

model {
    for (i in 1:N) {
        y[i] ~ lognormal(mu, sigma);
    }
}
"""

def lognormal_time_model_dat(df):
    sdf = df[~df['time_spent'].isnull()] # Some runs had glitchy time data; drop them
    runs = sdf.groupby(['worker_id', 'num_requested', 'accept_datetime'])
    changing_times = []
    within_times = []
    
    for name, run in runs:
        sdf = run.sort('answer_num', ascending=True)
        s_cats = sdf['subtree_root']
        s_times = sdf['time_spent']
        pairs = list(zip(s_cats[:-1], s_cats[1:], s_times[1:]))
        changing_times += [int(time) for cat1, cat2, time in pairs if cat1 != cat2]
        within_times += [int(time) for cat1, cat2, time in pairs if cat1 == cat2]

    changing_dat = { 'N': len(changing_times), 'y': changing_times }
    within_dat = { 'N': len(within_times), 'y': within_times }
    
    return [changing_dat, within_dat]
    

def view_lognormal_time_model_fit(change_fit, within_fit):
    for name, fit in [('CHANGE', change_fit), ('WITHIN', within_fit)]:
        la = fit.extract(permuted=True)
        mu = la['mu']
        sigma = la['sigma']
        
        print(name)
        hl, hr = hpd(mu, 0.95)
        print("mu:", hl, hr)
        hl, hr = hpd(sigma, 0.95)
        print("sigma:", hl, hr)
        
def hyp_test_lognormal_time_model(df, cache_key):
    dats = lognormal_time_model_dat(df)
    
    def testfunc(fits):
        prev_mu = None
        prev_sigma = None
        for name, fit in [('changing', fits[0]), ('within', fits[1])]:
            la = fit.extract(permuted=True)
            mu = la['mu']
            
            if prev_mu is None:
                prev_mu = hpd(mu, 0.95)
            else:
                mu = hpd(mu, 0.95)
                if max(mu) < min(prev_mu):
                    return True
        return False
    
    fits, success = hyp_test(dats, lognormal_time_model, testfunc, cache_key)
    
    return dat, fits, success

# %%
dat, fits, success = hyp_test_lognormal_time_model(df, 'test_lognormal_time_model')
print("Test workers spend more time between ideas than within: %s" % success)
# Out:
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# WARNING:pystan:COMPILING THE C++ CODE FOR MODEL anon_model NOW.
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 1).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 2).
# INFO:pystan:SAMPLING FOR MODEL anon_model NOW (CHAIN 3).
# Test workers spend more time between ideas than within: True

# %%
view_lognormal_time_model_fit(fits[0], fits[1])
# Out:
# CHANGE
# mu: 10.205745689 10.300704467
# sigma: 1.16272370503 1.22549338184
# WITHIN
# mu: 9.45486079731 9.64757284293
# sigma: 1.00821220466 1.136185237

# %% [markdown]
# # Classification Validity
#
# In our CHI reviews, there is concern over model validity and reliability. Here, we create data to try and create an upper bound on validity problems by looking at:
#
# + false positive classifications of ideas within trees
# + false negative classifications of ideas outside trees (i.e. idea should be in another tree, potentially leading to a tree merge)

# %%
import itertools
import nlp
from nltk.probability import FreqDist
reload(nlp)


def tree_text(tree):
    tree_df = df[df['subtree_root'] == tree]
    return ' '.join(list(tree_df['answer']))

def trees_to_text():
    ret = []
    for qc in cluster_forests.keys():
        trees = set(df[df['question_code'] == qc]['subtree_root'])
        ret.append((qc, [(tree, tree_text(tree)) for tree in trees]))
    
    return ret

scored_bags = None

def echo(p, x):
    print(p, end='\r')
    return x

# TODO: this only works for one question right now since I promote the results out of the loop
for qc, tree_texts in trees_to_text():
    bags_of_words = [(tree, set(nlp.extract_features(text, False, True, True)[0]))
                     for tree, text in tree_texts]
    
    corpus = sum([list(bag) for tree, bag in bags_of_words])
    word_frequencies = FreqDist(corpus)
    
    print("full bags")
    
    paired_bags = ((b1, b2) for b1, b2 in all_pairings(bags_of_words))
    scored_bags = [echo(i, (b1[0], b2[0], nlp.bag_of_words_cos_similarity_weighted(b1[1], b2[1], word_frequencies)))
                       for i, (b1, b2) in enumerate(paired_bags)]
# Out:
# full bags
# 2456
# 4820
# 7226
# 9743
# 12185
# 14511
# 17050
# 19332
# 21799
# 24230
# 26590
# 28831
# 31174
# 33302
# 35634
# 37400

# %%
top_bags = sorted(scored_bags, key=(lambda x: x[2]), reverse=True)

for tree1, tree2, score in top_bags[:50]:
    t1df = df[df['subtree_root'] == tree1]
    t2df = df[df['subtree_root'] == tree2]
    
    print('\n\n=====PAIR=====\n\n')
    #print(score)
    print(list(t1df['answer']))
    print('\n')
    print(list(t2df['answer']))
# Out:
# =====PAIR=====
#
#
# ['integrate facetime', 'use facetime for interviews']
#
#
# ['compatible with SKYPE for HITs that require interviews']
#
#
# =====PAIR=====
#
#
# ['mens app.', 'women app.']
#
#
# ['Clear Objectives (This hit is for MEN, 21-45, Working, etc...)']
#
#
# =====PAIR=====
#
#
# ['HIT Calendar']
#
#
# ['CALENDER', 'Abiliy to integrate with google calendar so that it can pop-up events of worker and tell whether to stop HIT because of it']
#
#
# =====PAIR=====
#
#
# ['HIT database that stores all past HITs', 'Create a HITS database', 'HIT database', 'HIT log+HIT database', 'HIT database+expanded header', 'hit database', 'Database for all your HITs', 'Database to see repeat hits and requestors']
#
#
# ['Expanded header']
#
#
# =====PAIR=====
#
#
# ['compatibility with Google Suite']
#
#
# [' compatibility with MS Office Suite - Ive seen many HITs that use Excel', 'microsoft word']
#
#
# =====PAIR=====
#
#
# ['Screen Saver Settings']
#
#
# ...

# %% [markdown]
# ## Same thing, based on tree size as priority

# %%
scored_trees = None

for qc in cluster_forests.keys():
    qcdf = df[df['question_code'] == qc]
    
    trees = set(qcdf['subtree_root'])
    tree_sizes = [(tree, len(qcdf[qcdf['subtree_root'] == tree])) for tree in trees]
    paired_trees = all_pairings(tree_sizes)
    
    scored_trees = [(t1[0], t2[0], t1[1] + t2[1]) for t1, t2 in paired_trees]

# %%
top_trees = sorted(scored_trees, key=(lambda x: x[2]), reverse=True)

for tree1, tree2, score in top_trees[:20]:
    t1df = df[df['subtree_root'] == tree1]
    t2df = df[df['subtree_root'] == tree2]
    
    print('\n\n=====PAIR=====\n\n')
    #print(score)
    print(list(t1df['answer']))
    print('\n')
    print(list(t2df['answer']))

# %% [markdown]
# ## Paired trees survey
#
# We sort all nodes by the number of instances in them. Then, we divide this space into 25 regions (5 x 5) and randomly sample 10 pairings from each region.

# %%
import random

def choose(n, k):
    return math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
    

def bin_sequence(seq, bin_val, num_bins):
    bin_vals = [bin_val(s) for s in seq]
    max_val = max(bin_vals)
    min_val = min(bin_vals)
    
    bins = [[] for i in range(num_bins)]
    
    for s in seq:
        val = bin_val(s)
        # min fixes inclusive upper bound
        b = min(num_bins - 1, math.floor(num_bins * float(val - min_val) / float(max_val - min_val)))
        bins[b].append(s)
        
    return bins

def sample_bin_pairings(bins, num_samples):
    samples = []
    
    for i, bn1 in enumerate(bins):
        for j, bn2 in enumerate(bins[:i+1]):
            combs = None
            if i != j:
                combs = [(i, j, e1, e2) for e1 in bn1 for e2 in bn2]
            else: # don't pair nodes with themselves
                combs = [(i, j, e1, e2) for k, e1 in enumerate(bn1[:-1])
                                  for e2 in bn1[k+1:]]
            
            bin_samples = random.sample(combs, min(len(combs), num_samples))
            print(i, j, len(bn1), len(bn2), len(bin_samples))
            samples.extend(bin_samples)
            
    return samples

def gen_survey_group_text(bin1, bin2, n1id, n2id):
    text = []
    text.append("\nGroup 1 (%d):" % n1id)
    
    n1df = df[df['idea'] == n1id]
    n2df = df[df['idea'] == n2id]
    
    n1_ideas = random.sample(list(n1df['answer']), min(3, len(n1df)))
    n2_ideas = random.sample(list(n2df['answer']), min(3, len(n2df)))
    
    for idea in n1_ideas:
        text.append('[ ] ' + idea)
        
    text.append("\nGroup 2 (%d):" % n2id)
    
    for idea in n2_ideas:
        text.append('[ ] ' + idea)
        
    return text

def gen_survey_questions(pairings):
    text = []
    text.append("""For each of the following questions, you will be presented two groups
                   of three ideas each. Each idea was given in response to this brainstorming
                   task:
                   
                   'Many people have old MP3 players or MP3 players that they no longer use.
                    Please brainstorm N uses for old MP3 players/MP3 players. Assume that
                    the devices' batteries no longer work, though they can be powered via
                    external power sources. Also be aware that devices may not have displays.
                    Be as specific as possible in your descriptions.'
                   
                   First, for each group, put a small X beside any idea that is not the same idea
                   as the others (with allowances for rephrasing). If none of the ideas are the same,
                   mark them all with Xs.
                   
                   Then, mark one of the 5
                   options for relationships between group 1 and group 2 of ideas.""")
    for i, pairing in enumerate(pairings):
        bin1, bin2, (n1id, _), (n2id, _) = pairing
    
        text.append("\n\n====================\nQuestion %d (%d x %d)\n====================" % (i+1, bin1, bin2))
        
        text.extend(gen_survey_group_text(bin1, bin2, n1id, n2id))
            
        text.append("\nRelationship between groups:")
        text.append('[ ] group 1 ideas are generalizations of group 2 ideas')
        text.append('[ ] group 2 ideas are generalizations of group 1 ideas')
        text.append('[ ] group 1 and group 2 are unrelated')
        text.append('[ ] group 1 and 2 are related, but not the same, and neither is a generalization of the other')
        text.append('[ ] group 1 and group 2 are the same')
        
    return '\n'.join(text)

# %%
for qc in cluster_forests.keys():
    qc_cdf = clusters_df[(clusters_df['question_code'] == qc) & (clusters_df['num_instances'] > 0)]
    
    nodes = list(zip(list(qc_cdf['idea']), list(qc_cdf['num_instances'])))
    bins = bin_sequence(nodes, lambda x: x[1], 5)
    pairings = sample_bin_pairings(bins, 10)
    random.shuffle(pairings)
    
    num_fixed_pairings = 10
    fixed_pairings = pairings[:num_fixed_pairings]
    num_judges = 8
    for j in range(num_judges):
        with open('ipython_output/validity_survey_judge_%s_%i.txt' % (qc, j), 'w') as f:
            rest_pairings = [p for i, p in enumerate(pairings[num_fixed_pairings:]) if i % num_judges == j]
            judge_pairings = fixed_pairings + rest_pairings
            f.write(gen_survey_questions(judge_pairings))
# Out:
# 0 0 1006 1006 10
# 1 0 28 1006 10
# 1 1 28 28 10
# 2 0 3 1006 10
# 2 1 3 28 10
# 2 2 3 3 3
# 3 0 0 1006 0
# 3 1 0 28 0
# 3 2 0 3 0
# 3 3 0 0 0
# 4 0 1 1006 10
# 4 1 1 28 10
# 4 2 1 3 3
# 4 3 1 0 0
# 4 4 1 1 0

# %% [markdown]
# ### Read and process results
#
# I hand-input the results from the printed surveys. Here we're going to input them and get a sense of what the surface of the error space looks like (as a fn of bin).

# %%
import csv
from collections import defaultdict
from mpl_toolkits.mplot3d import Axes3D

def get_results():
    survey_results = "%s/validity_survey/data.csv" % processed_data_folder
    with open(survey_results, 'r') as f:
        reader = csv.reader(f, delimiter=',')
        all_results = [row for row in reader if row[0] != 'judge' and row[5] != '?']
        
        return all_results
    
def cull_repeat_pairings(results):
    seen = set()
    for res in results:
        judge, n1id, n2id, bin1, bin2, rel, _, _, _, _ = res
        if (n1id, n2id) not in seen:
            seen.add((n1id, n2id))
            yield int(judge), int(n1id), int(n2id), int(bin1), int(bin2), int(rel)

def ancestors(f, nid):
    preds = f.predecessors(nid)
    return [ancestors(f, p) for p in preds] + preds
            
def get_node_relationship(n1id, n2id):
    f = cluster_forests['iPod']

    n1 = f.node[n1id]
    n2 = f.node[n2id]
    
    if n1['subtree_root'] != n2['subtree_root']:
        return 3
    elif n1id in ancestors(f, n2id):
        return 1
    elif n2id in ancestors(f, n1id):
        return 2
    else:
        return 4

def test_violation(guess, judge_rel, violation_type = "all"):
    fail = guess != int(judge_rel)
    if violation_type == 'all':
        return fail
    elif violation_type == 'parent_child':
        return fail and (judge_rel == 1 or judge_rel == 2 or guess == 1 or guess == 2)
    elif violation_type == 'artificial_parent':
        return fail and (judge_rel == 4 or guess == 4)
    elif violation_type == 'single_node_per_idea':
        return fail and (judge_rel == 5)
    
def gen_grid_bernoullis(results, violation_type = "all"):
    grid = defaultdict(list)
    bern_grid = dict()
    
    for judge, n1id, n2id, bin1, bin2, rel in results:
        guess = get_node_relationship(n1id, n2id)
        grid[(bin1, bin2)].append(int(test_violation(guess, rel, violation_type)))
    
    for k in grid.keys():
        trials = grid[k]
        p = calculate_posterior(sum(trials), len(trials))
        bern_grid[k] = (p[0], p[1], p[2], sum(trials) / len(trials))
        
    return bern_grid

def bern_grid_sym(bg, key1, key2):
    if (key1, key2) in bg:
        return bg[(key1, key2)]
    else:
        return bg[(key2, key1)]

def plot_bern_grid(bern_grid, title):
    # mean is 0, empirical mean is 3
    X, Y, Z = zip(*[(k[0], k[1], bern_grid[k][3]) for k in bern_grid])
    
    X2d, Y2d = np.meshgrid(np.arange(0, 5, 1), np.arange(0, 5, 1))
    Z2d = np.array([bern_grid_sym(bern_grid, x, y)[3] for x, y in zip(np.ravel(X2d), np.ravel(Y2d))])
    Z2d = Z2d.reshape(X2d.shape)
    
    plt.ion()
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111, projection='3d')
    ax.invert_xaxis()
    ax.plot_surface(X2d, Y2d, Z2d, shade=True, rstride=1, cstride=1)
    ax.set_zlim(0, 1)
    ax.set_xlabel("bin 1")
    ax.set_ylabel("bin 2")
    ax.set_zlabel("error proportion")
    ax.set_title(title)
    
    # headmap
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111)
    A = np.zeros((5,5))
    for x, y, z in zip(X, Y, Z):
        A[x, y] = z
        A[y, x] = z
    
    ax.imshow(A, interpolation='bilinear')
    ax.invert_yaxis()
    ax.set_xlabel("bin 1")
    ax.set_ylabel("bin 2")
    ax.set_title(title)
    
all_results = get_results()
culled = list(cull_repeat_pairings(all_results))
bern_grid = gen_grid_bernoullis(culled)
plot_bern_grid(bern_grid, 'all')

pc_bern_grid = gen_grid_bernoullis(culled, 'parent_child')
plot_bern_grid(pc_bern_grid, 'parent_child')

ap_bern_grid = gen_grid_bernoullis(culled, 'artificial_parent')
plot_bern_grid(ap_bern_grid, 'artificial_parent')

sn_bern_grid = gen_grid_bernoullis(culled, 'single_node_per_idea')
plot_bern_grid(sn_bern_grid, 'single_node_per_idea')

# %% [markdown]
# ### Inspect errors in bin regions
#
# We would like to be able to, for any of the above plots, zero in on a region and see the comparisons that we failed to properly identify.

# %%
code_legend = {
    1: '1 generalizes 2',
    2: '2 generalizes 1',
    3: 'unrelated',
    4: 'related',
    5: 'merge'
    }

def show_region_errors(results, bin1, bin2, violation_type='all'):
    r_in_bins = [r for r in results if set([r[3], r[4]]) == set([bin1, bin2])]
    
    for judge, n1id, n2id, bin1, bin2, rel in r_in_bins:
        guess = get_node_relationship(n1id, n2id)
        if test_violation(guess, rel, violation_type):
            print('\n'.join(gen_survey_group_text(bin1, bin2, n1id, n2id)))
            
            print("\nJudge %i said (%s), we said (%s)" % (judge, code_legend[rel], code_legend[guess]))
            print("===================================")
            
    
#show_region_errors(culled, 2, 2, 'artificial_parent')

# %% [markdown]
# ### IRR (mean cohen's kapp)
#
# Stolen from https://github.com/yorchopolis/kappa-stats/blob/master/kappa.py

# %%
def cohen_kappa(r1s, r2s, categories, kind):
    
    if kind not in ['unweighted', 'squared', 'linear']:
        print("Error: specify an accepted kappa type")
        return 0
    
    subjects = len(r1)
    
    # Build weight matrix
    weighted = np.empty((categories, categories))
    for i in range(categories):
            for j in range(categories):
                    if kind == 'unweighted':
                            weighted[i, j] = (i != j)
                    elif kind == 'squared':
                            weighted[i, j] = abs(i - j) ** 2
                    elif kind == 'linear':
                            weighted[i, j] = abs(i - j)
    
    # Build observed matrix
    observed = np.zeros((categories, categories))
    distributions = np.zeros((categories, 2))
    for k in range(subjects):
            observed[r1s[k], r2s[k]] += 1
            distributions[r1s[k], 0] += 1
            distributions[r2s[k], 1] += 1
            
    # Normalize observed and distribution arrays
    observed = observed / subjects
    distributions = distributions / subjects
    
    # Build expected array
    expected = np.empty((categories, categories))
    for i in range(categories):
            for j in range(categories):
                    expected[i, j] = distributions[i, 0] * distributions[j, 1]
                    
    # Calculate kappa
    kappa = 1.0 - (sum(sum(weighted * observed)) / sum(sum(weighted * expected)))
    
    return kappa

def paired_ratings(results, judge1, judge2):
    pr = defaultdict(list)
    
    for judge, n1id, n2id, bin1, bin2, rel, _, _, _, _ in results:
        if judge not in [judge1, judge2]:
            continue
        pr[(n1id, n2id)].append(int(rel) - 1)
        
    return [pr[k] for k in pr if len(pr[k]) > 1]

all_results = get_results()
judges = set([r[0] for r in all_results])
judge_pairings = list(all_pairings(list(judges)))

mean_kappa = 0
for judge1, judge2 in judge_pairings:
    print(paired_ratings(all_results, judge1, judge2), judge1, judge2)
    r1, r2 = zip(*paired_ratings(all_results, judge1, judge2))
    kappa = cohen_kappa(r1, r2, 5, 'unweighted')
    print(kappa)
    mean_kappa += kappa
mean_kappa /= len(judge_pairings)

print(mean_kappa)
